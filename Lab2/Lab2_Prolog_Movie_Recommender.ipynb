# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/apostolos-k/ntua-ai-notebooks/blob/main/Lab2/Lab2_Prolog_Movie_Recommender.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="/drive/My Drive/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd
path = '/content/drive/MyDrive/'
# Διάβασμα του αρχείου 'movie_metadata.csv'
data = pd.read_csv(path + "movies_metadata.csv")
# Στο csv υπαρχούν κελία με nan τιμές
# Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  return text

# %% [markdown]
# ###Ερώτημα 1α - Κόσμος

# %%
import ast
# Create World
# Ορίζουμε τον κόσμο μας
prolog = Prolog()

# Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
# αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}

for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, 'movie_title'))
  genre = clean_text(str(getattr(row, 'genres')))
  director_name = clean_text(getattr(row, 'director_name'))
  plot_keywords = clean_text(getattr(row, 'plot_keywords'))
  actor_1_name = clean_text(getattr(row, 'actor_1_name'))
  actor_2_name = clean_text(getattr(row, 'actor_2_name'))
  actor_3_name = clean_text(getattr(row, 'actor_3_name'))
  languages = clean_text(getattr(row, 'language'))
  production_companies = ast.literal_eval(getattr(row, 'production_companies'))   # String to list conversion
  production_countries = ast.literal_eval(getattr(row, 'production_countries'))
  title_year = clean_text(str(getattr(row, 'title_year')))

  # Some extra movie information
  rating = clean_text(str(getattr(row, 'vote_average')))
  duration = clean_text(str(getattr(row, 'duration')))
  gross = clean_text(str(getattr(row, 'gross')))
  popularity = clean_text(str(getattr(row, 'popularity')))

  if movie_title != 'UNK':
    # Gernes
    if genre != 'UNK':
      for g in genre.split("|"):
        literals.append("genre('"+ movie_title +"','"+ g +"')")
    # Director
    if director_name != 'UNK':
      literals.append("director('"+ movie_title +"','"+ director_name +"')")
    # Plot and Color
    bw = False
    if plot_keywords != 'UNK':
      for pk in plot_keywords.split("|"):
        if pk == "black and white":
          color = "blackwhite"
          literals.append("color('"+ movie_title +"','"+ color +"')")
          bw = True
        else:
          literals.append("keyword('"+ movie_title +"','"+ pk +"')")
      if not bw:
        color = "colored"
        literals.append("color('"+ movie_title +"','"+ color +"')")
    # Actors
    if actor_1_name != 'UNK':
      literals.append("actor('"+ movie_title +"','"+ actor_1_name +"')")
    if actor_2_name != 'UNK':
      literals.append("actor('"+ movie_title +"','"+ actor_2_name +"')")
    if actor_3_name != 'UNK':
      literals.append("actor('"+ movie_title +"','"+ actor_3_name +"')")
    # Language
    if languages != 'UNK':
      literals.append("language('"+ movie_title +"','"+ languages +"')")
    # Production Company
    if production_companies != "UNK":
      for company in production_companies:
        literals.append("company('"+ movie_title +"','"+ clean_text(company.get("name")) +"')")
    # Production Country
    if production_countries != "UNK":
      for country in production_countries:
        literals.append("country('"+ movie_title +"','"+ clean_text(country.get("name")) +"')")
    # Decade
    if title_year != 'UNK':
      year = float(title_year)
      a = int(year)%10
      decade = str(int(year - a + 10)) + 's'
      literals.append("decade('"+ movie_title +"','"+ decade +"')")
    # Stars
    if rating != 'UNK':
      if float(rating) >= 8.5:
        literals.append("stars('"+ movie_title +"','"+ "5" +"')")
      elif float(rating) < 8.5 and float(rating) >= 7.0:
        literals.append("stars('"+ movie_title +"','"+ "4" +"')")
      elif float(rating) < 7.0 and float(rating) >= 6.0:
        literals.append("stars('"+ movie_title +"','"+ "3" +"')")
      elif float(rating) < 6.0 and float(rating) >= 3.0:
        literals.append("stars('"+ movie_title +"','"+ "2" +"')")
      elif float(rating) < 3.0:
        literals.append("stars('"+ movie_title +"','"+ "1" +"')")
    # Duration
    if duration != 'UNK':
      if float(duration) >= 180.0:
        literals.append("duration('"+ movie_title +"','very long')")
      elif float(duration) < 180.0 and float(duration) >= 120.0:
        literals.append("duration('"+ movie_title +"','long')")
      elif float(duration) < 120.0 and float(duration) >= 60.0:
        literals.append("duration('"+ movie_title +"','normal')")
      elif float(duration) < 60.0:
        literals.append("duration('"+ movie_title +"','short')")
    # Gross
    if gross != 'UNK':
      if float(gross) >= 1000000000:
        literals.append("gross('"+ movie_title +"','"+ "billion" +"')")
      elif float(gross) < 1000000000 and float(gross) >= 750000000:
        literals.append("gross('"+ movie_title +"','"+ "expensive" +"')")
      elif float(gross) < 750000000 and float(gross) >= 350000000:
        literals.append("gross('"+ movie_title +"','"+ "normal" +"')")
      elif float(gross) < 350000000:
        literals.append("gross('"+ movie_title +"','"+ "cheap" +"')")
    # Popularity
    if popularity != 'UNK':
      if float(popularity) >= 150.000000:
        literals.append("popularity('"+ movie_title +"','"+ "blockbuster" +"')")
      if float(popularity) < 150.000000 and float(popularity) >= 90.000000:
        literals.append("popularity('"+ movie_title +"','"+ "popular" +"')")
      if float(popularity) < 90.000000 and float(popularity) >= 30.000000:
        literals.append("popularity('"+ movie_title +"','"+ "known" +"')")
      if float(popularity) < 30.000000:
        literals.append("popularity('"+ movie_title +"','"+ "unpopular" +"')")

# Η Prolog θέλει τα κατηγορήματά της με την σειρά
literals.sort()
for literal in literals:
  prolog.assertz(literal)

# Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
#prolog.consult(path + "db.pl")

# %% [markdown]
# ###Ερώτημα 1β - Κανόνες

# %%
# 1. Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
prolog.assertz('(commongenre4(X, Y) :- genre(X, G1), genre(Y, G1), genre(X, G2), genre(Y, G2), genre(X, G3), genre(Y, G3), genre(X, G4), genre(Y, G4), G1\=G2, G1\=G3, G1\=G4, G2\=G3, G2\=G4, G3\=G4, X\=Y)')

# 2. Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
prolog.assertz('(commongenre3(X, Y) :- genre(X, G1), genre(Y, G1), genre(X, G2), genre(Y, G2), genre(X, G3), genre(Y, G3), G1\=G2, G1\=G3, G2\=G3, X\=Y, \+ commongenre4(X,Y))')

# 3. Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
prolog.assertz('(commongenre1(X, Y) :- genre(X, G1), genre(Y, G1), G1\=G2, X\=Y, \+ commongenre3(X,Y))')

# 4. Κοινός σκηνοθέτης
prolog.assertz('(commondirector(X, Y) :- director(X, D), director(Y, D), X\=Y)')

# 5. Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
prolog.assertz('(commonplot3(X, Y) :- keyword(X, K1), keyword(Y, K1), keyword(X, K2), keyword(Y, K2), keyword(X, K3), keyword(Y, K3), K1\=K2, K1\=K3, K2\=K3, X\=Y)')

# 6. Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
prolog.assertz('(commonplot2(X, Y) :- keyword(X, K1), keyword(Y, K1), keyword(X, K2), keyword(Y, K2), K1\=K2, X\=Y, \+ commonplot3(X,Y))')

# 7. Ίδιους τους βασικούς ηθοποιούς (και τους 3)
prolog.assertz('(commonactors3(X, Y) :- actor(X, A1), actor(Y, A1), actor(X, A2), actor(Y, A2), actor(X, A3), actor(Y, A3), A1\=A2, A1\=A3, A2\=A3, X\=Y)')

# 8. Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
prolog.assertz('(commonactors2(X, Y) :- actor(X, A1), actor(Y, A1), actor(X, A2), actor(Y, A2), A1\=A2, X\=Y, \+ commonactors3(X,Y))')

# 9. Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
prolog.assertz('(commonactors1(X, Y) :- actor(X, A1), actor(Y, A1), X\=Y, \+ commonactors2(X,Y))')

# 10. Ίδια γλώσσα
prolog.assertz('(commonlanguage(X, Y) :- language(X, L), language(Y, L), X\=Y)')

# 11. Είναι έγχρωμες ή ασπρόμαυρες
prolog.assertz('(commoncolor(X, Y) :- color(X, C), color(Y, C), X\=Y)')

# 12. Κοινό studio παραγωγής
prolog.assertz('(commonstudio(X, Y) :- company(X, S), company(Y, S), X\=Y)')

# 13. Κοινή χώρα παραγωγής
prolog.assertz('(commoncountry(X, Y) :- country(X, C), country(Y, C), X\=Y)')

# 14. Ίδια δεκαετία
prolog.assertz('(commondecade(X, Y) :- decade(X, D), decade(Y, D), X\=Y)')

# 15. Αστέρια
prolog.assertz('(commonstars(X, Y) :- stars(X, S), stars(Y, S), X\=Y)')

# 16. Διάρκεια
prolog.assertz('(commonduration(X, Y) :- duration(X, D), duration(Y, D), X\=Y)')

# 17. Προϋπολογισμός
prolog.assertz('(commongross(X, Y) :- gross(X, G), gross(Y, G), X\=Y)')

# 18. Δημοτικότητα
prolog.assertz('(commonpopularity(X, Y) :- popularity(X, P), popularity(Y, P), X\=Y)')

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
# Similarity 5
prolog.assertz('(find_sim_5(X, Y) :- commonlanguage(X, Y), commonstudio(X, Y), commoncountry(X, Y), (commongenre4(X, Y); commonplot3(X, Y); commonactors3(X, Y)))')

# Similarity 4
prolog.assertz('(find_sim_4(X, Y) :- commonlanguage(X, Y), (commonstudio(X, Y); commoncountry(X, Y)), (commongenre3(X, Y); commonplot2(X, Y); commonactors2(X, Y)), \+ find_sim_5(X, Y))')

# Similarity 3
prolog.assertz('(find_sim_3(X, Y) :- commonlanguage(X, Y), (commongenre4(X, Y); commonplot3(X, Y); commonactors1(X, Y); commondirector(X, Y)), \+ find_sim_4(X, Y))')

# Similarity 2
prolog.assertz('(find_sim_2(X, Y) :- commonlanguage(X, Y), (commongenre1(X, Y); commonplot2(X, Y)), \+ find_sim_3(X, Y))')

# Similarity 1
prolog.assertz('(find_sim_1(X, Y) :- (commongenre1(X, Y); commonplot2(X, Y)), \+ find_sim_2(X, Y))')


def simple_recommender(movie):
    answers = []

# Προτεινόμενες ταινίες με ομοιότητα 5
    s5 = set()   # Store movies that match in s
    q = prolog.query("find_sim_5('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s5:
            s5.add(soln['M'])
    q.close()
    for mov in s5:
      answers.append((mov, 5))

# Προτεινόμενες ταινίες με ομοιότητα 4
    s4 = set()
    q = prolog.query("find_sim_4('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s4:
            s4.add(soln['M'])
    q.close()
    for mov in s4:
      answers.append((mov, 4))

# Προτεινόμενες ταινίες με ομοιότητα 3
    s3 = set()
    q = prolog.query("find_sim_3('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s3:
            s3.add(soln['M'])
    q.close()
    for mov in s3:
      answers.append((mov, 3))

# Προτεινόμενες ταινίες με ομοιότητα 2
    s2 = set()
    q = prolog.query("find_sim_2('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s2:
            s2.add(soln['M'])
    q.close()
    for mov in s2:
      answers.append((mov, 2))

# Προτεινόμενες ταινίες με ομοιότητα 1
    s1 = set()
    q = prolog.query("find_sim_1('" + movie +"',M)")
    for soln in q:
        m = soln['M']
        if m not in s1:
            s1.add(soln['M'])
    q.close()
    for mov in s1:
      answers.append((mov, 1))

    # For Part 2, so we can see the similarity level of each recommended movie
    print('Level 5: high similarity | Level 1: low similarity')
    print(f'Movie: {movie}')
    return answers

    # For Part 3, so we can apply different weights on each similarity level
    #return list(s5), list(s4), list(s3), list(s2), list(s1)

# %%
simple_recommender('Avatar')
# Out:
# Level 5: high similarity | Level 1: low similarity
# Movie: Avatar
# [('Predators', 5),
#  ('Dragonball Evolution', 5),
#  ('X-Men: Days of Future Past', 5),
#  ('Batman', 5),
#  ('Suicide Squad', 5),
#  ('Jupiter Ascending', 5),
#  ('The Wolverine', 5),
#  ('Aliens', 5),
#  ('Alien³', 5),
#  ('Jurassic World', 4),
#  ('Highlander', 4),
#  ('Silent Running', 4),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl', 4),
#  ('Platoon', 4),
#  ('Thor', 4),
#  ('Alien', 4),
#  ('Night at the Museum: Battle of the Smithsonian', 4),
#  ('Red Sonja', 4),
#  ('Star Wars: Episode I - The Phantom Menace', 4),
#  ('Street Fighter: The Legend of Chun-Li', 4),
#  ('Transformers: Revenge of the Fallen', 4),
#  ('Battle: Los Angeles', 4),
#  ('Mortal Kombat: Annihilation', 4),
#  ('Planet of the Apes', 4),
#  ('Green Lantern', 4),
#  ('The Thief and the Cobbler', 4),
#  ('X2', 4),
#  ('Underworld: Evolution', 4),
#  ('The Hunger Games: Mockingjay - Part 2', 4),
#  ('Daybreakers', 4),
#  ('The Four Feathers', 4),
#  ('The Lord of the Rings: The Fellowship of the Ring', 4),
#  ('Edge of Tomorrow', 4),
#  ('Journey to the Center of the Earth', 4),
#  ('Aliens in the Attic', 4),
#  ('Anacondas: The Hunt for the Blood Orchid', 4),
#  ('The Amazing Spider-Man 2', 4),
#  ('The Scorpion King', 4),
#  ('G.I. Joe: The Rise of Cobra', 4),
#  ('The Lost World: Jurassic Park', 4),
#  ('Star Trek V: The Final Frontier', 4),
#  ('Lara Croft: Tomb Raider', 4),
#  ('The League of Extraordinary Gentlemen', 4),
#  ('Oblivion', 4),
#  ('Bill & Teds Bogus Journey', 4),
#  ('Dune', 4),
#  ('Maleficent', 4),
#  ('The Hunger Games: Catching Fire', 4),
#  ('Men in Black', 4),
#  ('Serenity', 4),
#  ('Warcraft', 4),
#  ('The Black Hole', 4),
#  ('Spider-Man 3', 4),
#  ('Transformers: Age of Extinction', 4),
#  ('Enders Game', 4),
#  ('The Matrix Revolutions', 4),
#  ('Jason X', 4),
#  ('I, Robot', 4),
#  ('Captain America: The Winter Soldier', 4),
#  ('Pocahontas', 4),
#  ('The Time Machine', 4),
#  ('The 13th Warrior', 4),
#  ('Meet Dave', 4),
#  ('Brave', 4),
#  ('The Empire Strikes Back', 4),
#  ('Star Trek III: The Search for Spock', 4),
#  ('47 Ronin', 4),
#  ('RoboCop 3', 4),
#  ('Star Trek Beyond', 4),
#  ('The Saint', 4),
#  ('Treasure Planet', 4),
#  ('Logans Run', 4),
#  ('Mission to Mars', 4),
#  ('How to Train Your Dragon 2', 4),
#  ('Prince of Persia: The Sands of Time', 4),
#  ('Repo Man', 4),
#  ('Moonraker', 4),
#  ('Eragon', 4),
#  ('The Avengers', 4),
#  ('The Blood of Heroes', 4),
#  ('Terminator Genisys', 4),
#  ('X-Men Origins: Wolverine', 4),
#  ('Planet 51', 4),
#  ('Guardians of the Galaxy', 4),
#  ('The Day After Tomorrow', 4),
#  ('Pirates of the Caribbean: At Worlds End', 4),
#  ('Pacific Rim', 4),
#  ('Six-String Samurai', 4),
#  ('The Host', 4),
#  ('The Island', 4),
#  ('Aliens vs Predator: Requiem', 4),
#  ('Avengers: Age of Ultron', 4),
#  ('Night at the Museum', 4),
#  ('Last Action Hero', 4),
#  ('Iron Man', 4),
#  ('Pirates of the Caribbean: On Stranger Tides', 4),
#  ('The Hobbit: The Battle of the Five Armies', 4),
#  ('The Core', 4),
#  ('Mirror Mirror', 4),
#  ('Renaissance', 4),
#  ('Zathura: A Space Adventure', 4),
#  ('Congo', 4),
#  ('Men in Black II', 4),
#  ('Ant-Man', 4),
#  ('Delgo', 4),
#  ('Superman IV: The Quest for Peace', 4),
#  ('Babylon A.D.', 4),
#  ('Transformers: Dark of the Moon', 4),
#  ('John Carter', 4),
#  ('Star Trek', 4),
#  ('The Iron Giant', 4),
#  ('Star Wars', 4),
#  ('The Brothers Grimm', 4),
#  ('Battleship', 4),
#  ('X-Men', 4),
#  ('Iron Man 2', 4),
#  ('The Astronauts Wife', 4),
#  ('Highlander: The Final Dimension', 4),
#  ('Wild Wild West', 4),
#  ('Pirates of the Caribbean: Dead Mans Chest', 4),
#  ('Steel', 4),
#  ('Cirque du Freak: The Vampires Assistant', 4),
#  ('The Abyss', 4),
#  ('BloodRayne', 4),
#  ('Journey 2: The Mysterious Island', 4),
#  ('Stargate: The Ark of Truth', 4),
#  ('Divergent', 4),
#  ('The Thin Red Line', 4),
#  ('Knowing', 4),
#  ('Lara Croft Tomb Raider: The Cradle of Life', 4),
#  ('Chicken Little', 4),
#  ('G.I. Joe: Retaliation', 4),
#  ('Escape from L.A.', 4),
#  ('Mad Max: Fury Road', 4),
#  ('Thor: The Dark World', 4),
#  ('The Last Legion', 4),
#  ('The Sorcerers Apprentice', 4),
#  ('Independence Day: Resurgence', 4),
#  ('The Hitchhikers Guide to the Galaxy', 4),
#  ('Conan the Barbarian', 4),
#  ('Inception', 4),
#  ('E.T. the Extra-Terrestrial', 4),
#  ('A Sound of Thunder', 4),
#  ('Starship Troopers', 4),
#  ('Star Trek: Generations', 4),
#  ('Resident Evil: Afterlife', 4),
#  ('Clash of the Titans', 4),
#  ('The Last Witch Hunter', 4),
#  ('Predator', 4),
#  ('9', 4),
#  ('The Borrowers', 4),
#  ('Armageddon', 4),
#  ('Home', 4),
#  ('Paycheck', 4),
#  ('Fantastic Four', 4),
#  ('Independence Day', 4),
#  ('Teenage Mutant Ninja Turtles: Out of the Shadows', 4),
#  ('Dungeons & Dragons: Wrath of the Dragon God', 4),
#  ('The Lord of the Rings: The Two Towers', 4),
#  ('Reign of Fire', 4),
#  ('Cypher', 4),
#  ('Monkeybone', 4),
#  ('Star Trek: First Contact', 4),
#  ('After Earth', 4),
#  ('Return of the Jedi', 4),
#  ('Highlander: Endgame', 4),
#  ('Spy Kids 3-D: Game Over', 4),
#  ('U.F.O.', 4),
#  ('We Were Soldiers', 4),
#  ('Spider-Man 2', 4),
#  ('The Forbidden Kingdom', 4),
#  ('In the Name of the King: A Dungeon Siege Tale', 4),
#  ('The Hobbit: An Unexpected Journey', 4),
#  ('2012', 4),
#  ('Conan the Destroyer', 4),
#  ('You Only Live Twice', 4),
#  ('Fantastic 4: Rise of the Silver Surfer', 4),
#  ('The Mummy Returns', 4),
#  ('Southland Tales', 4),
#  ('Interstellar', 4),
#  ('Iron Man 3', 4),
#  ('Titan A.E.', 4),
#  ('Total Recall', 4),
#  ('Megaforce', 4),
#  ('My Super Ex-Girlfriend', 4),
#  ('The Amazing Spider-Man', 4),
#  ('Time Bandits', 4),
#  ('Timeline', 4),
#  ('Star Trek: Insurrection', 4),
#  ('The Time Travelers Wife', 4),
#  ('G-Force', 4),
#  ('Star Wars: Episode II - Attack of the Clones', 4),
#  ('Star Trek II: The Wrath of Khan', 4),
#  ('The Matrix Reloaded', 4),
#  ('Star Trek Into Darkness', 4),
#  ('Star Trek VI: The Undiscovered Country', 4),
#  ('The Mummy: Tomb of the Dragon Emperor', 4),
#  ('TRON: Legacy', 4),
#  ('Krull', 4),
#  ('The Lord of the Rings: The Return of the King', 4),
#  ('Batman v Superman: Dawn of Justice', 4),
#  ('Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 4),
#  ('The Mortal Instruments: City of Bones', 4),
#  ('X-Men: The Last Stand', 4),
#  ('Hellboy II: The Golden Army', 4),
#  ('Star Wars: Episode III - Revenge of the Sith', 4),
#  ('Tank Girl', 4),
#  ('The Last Airbender', 4),
#  ('Star Trek: Nemesis', 4),
#  ('Jurassic Park III', 4),
#  ('Jimmy Neutron: Boy Genius', 4),
#  ('The Hunger Games', 4),
#  ('Star Wars: Clone Wars: Volume 1', 3),
#  ('The Covenant', 3),
#  ('Predators', 3),
#  ('Crossroads', 3),
#  ('Beastmaster 2: Through the Portal of Time', 3),
#  ('Dragonball Evolution', 3),
#  ('X-Men: Days of Future Past', 3),
#  ('Thunderbirds', 3),
#  ('Aliens', 3),
#  ('Superman Returns', 3),
#  ('Shadow Conspiracy', 3),
#  ('Terminator 2: Judgment Day', 3),
#  ('The Cold Light of Day', 3),
#  ('Out of the Furnace', 3),
#  ('Drumline', 3),
#  ('Baby Mama', 3),
#  ('The Fifth Element', 3),
#  ('Teenage Mutant Ninja Turtles', 3),
#  ('Underworld: Rise of the Lycans', 3),
#  ('Final Fantasy: The Spirits Within', 3),
#  ('Batman', 3),
#  ('Titanic', 3),
#  ('Jupiter Ascending', 3),
#  ('Suicide Squad', 3),
#  ('Superman', 3),
#  ('The Ice Storm', 3),
#  ('Race to Witch Mountain', 3),
#  ('Center Stage', 3),
#  ('Sheena', 3),
#  ('Vamps', 3),
#  ('The Book of Life', 3),
#  ('You Again', 3),
#  ('The Shadow', 3),
#  ('The Losers', 3),
#  ('The Words', 3),
#  ('True Lies', 3),
#  ('Mystery Men', 3),
#  ('The Terminator', 3),
#  ('Man of Steel', 3),
#  ('Small Soldiers', 3),
#  ('Cedar Rapids', 3),
#  ('Superman III', 3),
#  ('Spawn', 3),
#  ('The Wolverine', 3),
#  ('Superman II', 3),
#  ('Alien³', 3),
#  ('Teenage Mutant Ninja Turtles III', 3),
#  ('Galaxy Quest', 3),
#  ('Galaxina', 3),
#  ('Silent Running', 2),
#  ('We Were Soldiers', 2),
#  ('Treasure Planet', 2),
#  ('Platoon', 2),
#  ('Alien', 2),
#  ('Stargate: The Ark of Truth', 2),
#  ('The Thin Red Line', 2),
#  ('Mission to Mars', 2),
#  ('Repo Man', 2),
#  ('Battle: Los Angeles', 2),
#  ('Chicken Little', 2),
#  ('Planet of the Apes', 2),
#  ('Green Lantern', 2),
#  ('You Only Live Twice', 2),
#  ('Terminator Genisys', 2),
#  ('Interstellar', 2),
#  ('Titan A.E.', 2),
#  ('Planet 51', 2),
#  ('The Four Feathers', 2),
#  ('Edge of Tomorrow', 2),
#  ('The Hitchhikers Guide to the Galaxy', 2),
#  ('The Time Travelers Wife', 2),
#  ('Predator', 2),
#  ('The Astronauts Wife', 2),
#  ('Renaissance', 2),
#  ('Lockout', 2),
#  ('Home', 2),
#  ('Enders Game', 2),
#  ('Jason X', 2),
#  ('I, Robot', 2),
#  ('Captain America: The Winter Soldier', 2),
#  ('Pocahontas', 2),
#  ('Independence Day', 2),
#  ('Cypher', 2),
#  ('Meet Dave', 2),
#  ('Jimmy Neutron: Boy Genius', 2),
#  ('Jupiter Ascending', 1),
#  ('Cargo', 1),
#  ('Moon', 1),
#  ('A Monster in Paris', 1)]

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {0:5, 1:4, 2:3, 3:2, 4:1} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')
        print("rating:",rating,", movie:",movie)

        similar_movies = simple_recommender(movie)

        # Apply different weights on each similarity level
        for i in range(5):
            for similar_movie in similar_movies[i]:
                if similar_movie not in movie_score:
                    movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[4] # If is first time movie appears, add it with the minimum weight
                else:
                    movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[i] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score:  # αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0))  # heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))  # έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            # η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: # δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 5)
    print(movie_score)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# rating: 4.0 , movie: Horrible Bosses
# rating: 5.0 , movie: Madagascar
# rating: 5.0 , movie: Terminator 3: Rise of the Machines
# rating: 2.0 , movie: Dragonslayer
# rating: 3.0 , movie: Army of Darkness
# {'Going the Distance': 0.5, 'Horrible Bosses 2': 0.5, 'Pacific Rim': 0.5, 'Paul': 0.5, 'Epic': 0.5, 'Hall Pass': 0.5, 'The Change-Up': 0.5, 'Race': 0.5, 'Four Christmases': 0.5, 'Identity Thief': 0.5, 'Up in the Air': 0.5, 'Hancock': 0.5, 'The Campaign': 0.5, 'Juno': 0.5, 'Couples Retreat': 0.5, 'Madagascar: Escape 2 Africa': 4, 'Roar': 3, 'The Nutty Professor': 1, 'Bamboozled': 1, 'Bad Company': 1, 'Tales from the Crypt: Demon Knight': 1, 'A Low Down Dirty Shame': 1, 'Antz': 1, 'Menace II Society': 1, 'Reign Over Me': 1, 'Six Days Seven Nights': 1, 'The Longest Yard': 1, 'Grown Ups 2': 1, 'Penguins of Madagascar': 1, 'Madagascar 3: Europes Most Wanted': 1, 'The Matrix Revolutions': 4, 'The Matrix Reloaded': 4, 'Blade Runner': 4, 'The Matrix': 4, 'Interstellar': 4, 'Terminator Salvation': 4, 'Jurassic World': 1, 'Doomsday': 1, 'Pandorum': 1, 'Alien Zone': 1, 'Gamer': 1, 'Zombie Hunter': 1, 'Alien': 1, 'Repo Men': 1, 'Death Race': 1, 'The Book of Eli': 1, 'Street Fighter: The Legend of Chun-Li': 1, 'Indiana Jones and the Kingdom of the Crystal Skull': 3, 'Planet of the Apes': 1, 'Green Lantern': 1, 'X2': 1, 'Underworld: Evolution': 1, 'Daybreakers': 1, 'Outbreak': 1, 'Anacondas: The Hunt for the Blood Orchid': 1, 'G.I. Joe: The Rise of Cobra': 1, 'Looper': 1, 'Star Trek V: The Final Frontier': 1, 'The League of Extraordinary Gentlemen': 1, 'Fortress': 3, 'The Darkest Hour': 1, 'Pitch Black': 1, 'Lake Placid': 1, 'Impostor': 1, 'Ultraviolet': 1, 'Dylan Dog: Dead of Night': 1, 'Serenity': 1, 'Split Second': 1, 'Meteor': 1, 'Spawn': 1, 'Left Behind': 1, 'Elysium': 1, 'Star Trek III: The Search for Spock': 1, 'The Covenant': 1, 'The Saint': 1, 'RoboCop 3': 3, 'Logans Run': 3, 'World Trade Center': 3, 'The One': 1, 'Aliens': 1, 'A View to a Kill': 3, 'Moonraker': 1, 'X-Men Origins: Wolverine': 1, 'Terminator Genisys': 1, 'The Thirteenth Floor': 3, 'The Day After Tomorrow': 1, 'Transcendence': 3, 'The Host': 1, 'The Island': 1, 'Aliens vs Predator: Requiem': 1, 'Race to Witch Mountain': 1, '2001: A Space Odyssey': 3, 'The Core': 1, 'Congo': 1, 'Men in Black II': 3, 'Babylon A.D.': 1, 'I Am Legend': 3, 'Predator 2': 1, 'Riddick': 1, 'The Maze Runner': 1, 'The Spirit': 1, 'Dawn of the Planet of the Apes': 1, 'Battleship': 1, 'Dragonball Evolution': 1, 'The Abyss': 1, 'Terminator 2: Judgment Day': 3, 'Knowing': 1, 'G.I. Joe: Retaliation': 1, 'Escape from L.A.': 1, 'The Fifth Element': 1, 'Mad Max: Fury Road': 1, 'Underworld: Rise of the Lycans': 1, 'Final Fantasy: The Spirits Within': 1, 'Hav Plenty': 1, 'Raiders of the Lost Ark': 3, 'In Time': 1, 'Inception': 1, 'eXistenZ': 1, 'A Sound of Thunder': 1, 'Starship Troopers': 1, 'Deep Blue Sea': 1, 'Star Trek: Generations': 1, 'Predator': 1, '9': 3, 'RoboCop': 3, 'The Shadow': 1, 'Armageddon': 1, 'Paycheck': 1, 'Carriers': 1, 'The Terminator': 1, 'Rise of the Planet of the Apes': 1, 'Star Trek: First Contact': 1, 'Hollow Man': 1, 'Face/Off': 1, 'Predators': 1, 'Timecop': 1, 'The Devils Tomb': 1, 'They Live': 1, 'Minority Report': 1, 'Equilibrium': 1, 'Southland Tales': 1, 'A.I. Artificial Intelligence': 3, 'Star Trek: Insurrection': 1, 'Megiddo: The Omega Code 2': 1, 'Stake Land': 1, 'Star Trek II: The Wrath of Khan': 1, 'Star Trek VI: The Undiscovered Country': 1, 'TRON: Legacy': 3, 'Red Planet': 1, 'World War Z': 1, 'Children of Men': 1, 'Phantasm II': 1, 'Capricorn One': 1, 'X-Men: The Last Stand': 1, 'Chain Reaction': 1, 'Echo Dr.': 1, 'Virtuosity': 1, 'Surrogates': 1, 'Star Trek: Nemesis': 1, 'Jurassic Park III': 1, 'Me and Orson Welles': 1, 'Romeo + Juliet': 1, 'I, Robot': 1, 'Disturbing Behavior': 1, 'Bully': 1, 'U-571': 1, 'The Rainmaker': 1, 'Shopgirl': 1, 'Igby Goes Down': 1, 'Breakdown': 1, 'Automata': 1, 'Metropolis': 1, 'Akira': 1, 'Moon': 1, 'Harry Potter and the Chamber of Secrets': 0, 'Harry Potter and the Prisoner of Azkaban': 0, 'Harry Potter and the Goblet of Fire': 0, 'Seventh Son': 0, 'Harry Potter and the Order of the Phoenix': 0, 'Warcraft': 0, 'Your Highness': 0, 'T ...
# 0it [00:00, ?it/s]
# rating: 0.5 , movie: Rebecca
# rating: 4.0 , movie: Horrible Bosses
# rating: 5.0 , movie: The Wedding Planner
# rating: 4.0 , movie: Barry Lyndon
# rating: 1.0 , movie: Alexander
# {'Moby Dick': -3, 'Open Secret': -3, 'New in Town': -3, 'The Silence of the Lambs': -3, 'The X Files': -3, 'The Dead Zone': -3, 'One Day': -3, 'Forrest Gump': -3, 'Good Luck Chuck': -3, 'The Time Travelers Wife': -3, 'Love Letters': -3, 'The Number 23': -3, 'Black Swan': -3, 'The Hunger Games: Catching Fire': -3, 'The Dilemma': -3, 'The Prestige': -3, 'Something Borrowed': -3, 'The Roommate': -3, 'Beastly': -3, 'Dear John': -5.0, 'The Village': -3, 'In Dreams': -3, 'The Bourne Supremacy': -3, 'The Great Gatsby': -3, 'High Crimes': -3, 'Mean Creek': -3, 'Stranger Than Fiction': -3, 'Anne of Green Gables': -3, 'Exorcist: The Beginning': -3, 'Homefront': -3, 'North Country': -3, 'Snakes on a Plane': -3, 'Cat on a Hot Tin Roof': -1, 'Conspiracy Theory': -1, 'Psycho': -1, 'Notes on a Scandal': -1, 'Stir of Echoes': -1, 'Tycoon': -3.0, 'Heavenly Creatures': -1, 'The Trouble with Harry': -1, 'Alex & Emma': -1, 'Torn Curtain': -1, 'Frenzy': -1, 'Solomon and Sheba': -2.5, 'Spellbound': -1, 'Family Plot': -1, 'The Postman Always Rings Twice': -1, 'Topaz': -1, 'Love and Death on Long Island': -1, 'The Woman in Black': -1, 'Perfume: The Story of a Murderer': -1, 'Iris': -1, 'Death at a Funeral': -1, 'Swimming Pool': -1, 'Juliet and Alfa Romeo': -1, 'Last Orders': -1, 'Volver': -1, '13 Hours: The Secret Soldiers of Benghazi': -1, 'The Lady from Shanghai': -1, 'The Hunchback of Notre Dame': -1, 'The Great Beauty': -1, 'Going the Distance': 0.5, 'Horrible Bosses 2': 0.5, 'Pacific Rim': 0.5, 'Paul': 0.5, 'Epic': 0.5, 'Hall Pass': 0.5, 'The Change-Up': 0.5, 'Race': 0.5, 'Four Christmases': 0.5, 'Identity Thief': 0.5, 'Up in the Air': 0.5, 'Hancock': 0.5, 'The Campaign': 0.5, 'Juno': 0.5, 'Couples Retreat': 0.5, 'Shes the One': 3, '27 Dresses': 3, 'Leap Year': 3, 'The Five-Year Engagement': 3, 'Four Weddings and a Funeral': 1, 'Bringing Down the House': 1, 'Bedtime Stories': 1, 'Contact': 1, 'Frailty': 1, 'How to Lose a Guy in 10 Days': 1, 'Reign of Fire': 1, 'Magic Mike': 1, 'Bernie': 1, 'Cheaper by the Dozen 2': 1, 'My Best Friends Wedding': 1, 'Thirteen Conversations About One Thing': 1, 'Hairspray': 1, 'A Walk to Remember': 1, 'Lone Star': 1, 'Rock of Ages': 1, 'The Pacifier': 1, 'The Story of Us': 1, 'The English Patient': 0.5, 'In the Heart of the Sea': -2.0, 'The Last Samurai': -2.0, 'Proof of Life': -2.0, 'The Charge of the Light Brigade': -2.0, 'Letters from Iwo Jima': -2.0, 'The Land Girls': -0.5, 'Platoon': -0.5, 'The Man in the Iron Mask': -0.5, 'The Proposition': -0.5, 'Apocalypto': -0.5, 'Big Miracle': -0.5, 'Kama Sutra - A Tale of Love': -0.5, 'The Blue Lagoon': -0.5, 'Sahara': -0.5, 'Nomad: The Warrior': -0.5, 'Lone Wolf McQuade': -0.5, 'Tears of the Sun': -0.5, 'Gods and Generals': -0.5, '300': -0.5, 'Tracker': -0.5, 'A Passage to India': -0.5, 'Gettysburg': -0.5, 'Lucky Numbers': -0.5, 'American Ninja 2: The Confrontation': -0.5, 'Patton': -0.5, 'Maleficent': -0.5, 'The Adventures of Huck Finn': -0.5, 'The Wind That Shakes the Barley': -0.5, 'The Best Years of Our Lives': -0.5, 'Force 10 from Navarone': -0.5, 'Cinderella Man': -0.5, 'Anna and the King': -0.5, 'Broken Arrow': -0.5, 'Seven Years in Tibet': -0.5, 'Bubble Boy': -0.5, 'The Finest Hours': -0.5, 'The Quiet American': -0.5, 'Inchon': -0.5, 'London': -0.5, 'A Farewell to Arms': -0.5, 'Young Sherlock Holmes': -0.5, '47 Ronin': -0.5, 'The Saint': -0.5, 'The Twilight Saga: Eclipse': -0.5, 'Logans Run': -0.5, 'Across the Universe': -0.5, 'One Mans Hero': -0.5, 'A Guy Named Joe': -0.5, 'The Other Side of Heaven': -0.5, 'Prince of Persia: The Sands of Time': -0.5, 'Love Me Tender': -0.5, 'All Is Lost': -0.5, 'The Negotiator': -0.5, 'Executive Decision': -0.5, 'Extreme Ops': -0.5, 'King Kong': -0.5, 'Alive': -0.5, 'The Bodyguard': -0.5, 'The Great Raid': -0.5, 'The Devils Double': -0.5, 'Cleopatra': -0.5, 'Sweet Sweetbacks Baadasssss Song': -0.5, 'The Twilight Saga: New Moon': -0.5, 'Gladiator': -0.5, 'The Hunting Party': -0.5, 'The Imitation Game': -0.5, 'Boom Town': -0.5, ' ...
# 0it [00:00, ?it/s]
# rating: 5.0 , movie: Dances with Wolves
# rating: 1.0 , movie: Notting Hill
# rating: 2.5 , movie: Romeo + Juliet
# rating: 5.0 , movie: Amélie
# rating: 4.0 , movie: The Transporter
# {'Quigley Down Under': 1, 'The Proposition': 1, 'Girl, Interrupted': 3, 'Cold Mountain': 3, 'True Grit': 1, 'Tombstone': 1, 'The Revenant': 3, 'The Timber': 1, '21 Grams': 3, 'Young Guns': 1, 'Anna Karenina': 3, 'Dead Man Walking': 3, 'Magnolia': 3, 'The Homesman': 3, 'The Fisher King': 3, 'The Three Burials of Melquiades Estrada': 1, 'The Great Escape': 3, 'Shanghai Noon': 3, 'In Dreams': 3, 'Pocahontas': 3, 'Swimming Pool': 3, 'Doctor Zhivago': 4, 'John Carter': 3, 'Finding Forrester': 3, 'Its a Wonderful Life': 3, 'The Last Samurai': 1, 'Die Hard: With a Vengeance': 1, 'Open Range': 1, 'Independence Day': 1, 'Unnatural': 1, 'The Postman': 1, 'Lost in Translation': 1, '2046': 1, 'Dude, Where’s My Car?': -1.5, 'Walking and Talking': -0.5, 'The Broken Hearts Club: A Romantic Comedy': -0.5, 'Crossroads': -0.5, 'Buffalo 66': -0.5, 'Hope Springs': -0.5, 'New York Stories': -0.5, 'Wristcutters: A Love Story': -0.5, 'Quartet': -0.5, 'Anywhere But Here': -0.5, 'Varsity Blues': -0.5, 'Shopgirl': -0.5, 'Rock of Ages': -0.5, 'Chocolat': -0.5, 'The Wendell Baker Story': -0.5, 'The Last Five Years': -0.5, 'Hannah Montana: The Movie': -0.5, 'Maid in Manhattan': -0.5, 'Kiss the Bride': -0.5, 'Riding in Cars with Boys': -0.5, 'How Do You Know': -0.5, 'Forrest Gump': -0.5, 'Molly': -0.5, 'Morning Glory': -0.5, 'A Good Year': -0.5, 'Double Take': -0.5, 'The Apartment': -0.5, 'Tadpole': -0.5, 'High School Musical 3: Senior Year': -0.5, 'Living Out Loud': -0.5, 'Tiny Furniture': -0.5, 'Boys and Girls': -1.5, 'The Sessions': -0.5, 'About a Boy': -1.5, 'Shes the Man': -0.5, 'The Talented Mr. Ripley': -1.5, 'Cheri': -0.5, 'Crazy, Stupid, Love.': -0.5, 'Love & Other Drugs': -0.5, 'Bubble Boy': -0.5, 'Cant Hardly Wait': -0.5, 'Four Christmases': -0.5, 'Away We Go': -0.5, 'The Family Stone': -0.5, 'Letters to Juliet': -0.5, 'Andersons Cross': -0.5, 'Inherent Vice': -0.5, 'Meet Dave': -1.5, 'The Proposal': -0.5, 'Peggy Sue Got Married': -0.5, 'Tin Cup': -0.5, 'Outside Providence': -0.5, 'The Mirror Has Two Faces': -0.5, 'The Four Seasons': -0.5, 'The Rules of Attraction': -0.5, 'Madeas Family Reunion': -0.5, 'Big': -0.5, 'Chasing Amy': -0.5, 'Bend It Like Beckham': -0.5, 'Bridget Joness Diary': -1.5, 'Juno': -0.5, 'LOL': -0.5, 'Admission': -0.5, 'Drumline': -0.5, 'Divine Secrets of the Ya-Ya Sisterhood': -0.5, 'You Will Meet a Tall Dark Stranger': -0.5, 'What Planet Are You From?': -0.5, 'Full Frontal': -0.5, '(500) Days of Summer': -0.5, '10 Things I Hate About You': -0.5, 'Where the Heart Is': -0.5, 'Don Jon': -0.5, 'Good Luck Chuck': -0.5, 'Confessions of a Dangerous Mind': -0.5, 'Barry Munday': -0.5, 'Good Dick': -0.5, 'Love Jones': -0.5, 'The Front Page': -0.5, 'The Spectacular Now': -0.5, 'How to Deal': -0.5, 'The Brothers': -0.5, 'Lovely & Amazing': -0.5, 'Everything Must Go': -0.5, 'Loser': -0.5, 'Youth in Revolt': -0.5, 'When Harry Met Sally...': -0.5, 'The Perez Family': -0.5, 'Lars and the Real Girl': -0.5, 'School for Scoundrels': -0.5, 'Ever After: A Cinderella Story': -0.5, 'Return to Me': -0.5, 'The Incredibly True Adventure of Two Girls In Love': -0.5, 'A Mighty Heart': -1.5, 'Cyrus': -0.5, 'Drive Me Crazy': -0.5, 'American Desi': -0.5, 'My Beautiful Laundrette': -0.5, 'The Good Night': -0.5, 'My Last Day Without You': -0.5, 'Beginners': -0.5, 'Hitch': -0.5, 'Stranger Than Fiction': -0.5, 'Focus': -0.5, 'Dear Wendy': -0.5, 'Jesus Son': -0.5, 'Going the Distance': -0.5, 'Joe Dirt': -0.5, 'Larry Crowne': -0.5, 'Man on the Moon': -0.5, 'Love Actually': -1.5, 'Sweet Charity': -0.5, 'The Brothers Bloom': -0.5, 'In Good Company': -0.5, 'Jerry Maguire': -0.5, 'The Brothers McMullen': -0.5, 'Don Juan DeMarco': -0.5, 'Raising Helen': -0.5, 'The Wood': -0.5, 'Just My Luck': -0.5, 'Little Black Book': -0.5, 'Me and Orson Welles': -0.5, 'How Stella Got Her Groove Back': -0.5, 'Shall We Dance?': -0.5, 'The Battle of Shaker Heights': -0.5, 'The Muppet Movie': -1.5, 'Enough Said': -0.5, 'Trust the Man': -0.5, 'Take Me Home Tonight': -0.5, 'An Ideal H ...
# 0it [00:00, ?it/s]
# rating: 4.0 , movie: Shine a Light
# rating: 2.5 , movie: Maurice
# rating: 5.0 , movie: A Woman, a Gun and a Noodle Shop
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 3.0 , movie: Wag the Dog
# {'Almost Famous': 1.5, 'August Rush': 1.5, 'Center Stage': 1.5, 'Im Not There.': 1.5, 'The Blues Brothers': 1.5, 'Walk Hard: The Dewey Cox Story': 1.5, 'Hairspray': 1.5, 'This Is It': 1.5, 'Casino': 0.5, 'Gangs of New York': 0.5, 'New York, New York': 0.5, 'The Aviator': 0.5, 'Taxi Driver': 0.5, 'Mean Streets': 0.5, 'Raging Bull': 0.5, 'The Last Waltz': 0.5, 'Hugo': 0.5, 'Shutter Island': 0.5, 'Cape Fear': 0.5, 'Alvin and the Chipmunks': 0.5, 'The Color of Money': 0.5, 'The Departed': 0.5, 'Kundun': 0.5, 'Bringing Out the Dead': 0.5, 'The Last Temptation of Christ': 0.5, 'Johnny Suede': 0.5, 'The Age of Innocence': 0.5, 'As It Is in Heaven': 0.5, 'Once': 0.5, 'My Beautiful Laundrette': 0, 'Chicken Tikka Masala': 0, 'Weekend': 0, 'Florence Foster Jenkins': 0, 'The White Countess': 0, 'A Room with a View': 0, 'The Remains of the Day': 0, 'Two Weeks Notice': 0, 'The Wicked Lady': 0, 'Music and Lyrics': 0, 'Howards End': 0, 'Jefferson in Paris': 0, 'The City of Your Final Destination': 0, 'Mambo Italiano': 0, 'Extreme Ops': 0, 'Saved!': 0, 'Notting Hill': 0, 'In & Out': 0, 'Bridget Joness Diary': 0, 'Sense and Sensibility': 0, 'The Broken Hearts Club: A Romantic Comedy': 0, 'Tiger Orange': 0, 'Beginners': 0, 'D.E.B.S.': 0, 'Latter Days': 0, 'A Home at the End of the World': 0, 'My Own Private Idaho': 0, 'American Beauty': 0, 'Brüno': 0, 'Y Tu Mamá También': 0, 'House of Flying Daggers': 1, 'The Monkey King 2': 1, 'The Flowers of War': 1, 'Coming Home': 1, 'Curse of the Golden Flower': 1, 'Hero': 1, 'Lost in Translation': 0, 'An Education': 0, 'The Last Samurai': 0, 'JFK': 0, 'State of Play': 0, 'Happiness': 0, 'Wild Things': 0, 'Escape from New York': 0, 'Mr. Smith Goes to Washington': 0, 'The Jacket': 0, 'Edge of Tomorrow': 0, 'Austin Powers: The Spy Who Shagged Me': 0, 'Derailed': 0, 'Swing Vote': 0, 'Charlie Wilsons War': 0, 'Conspiracy Theory': 0, 'Lions for Lambs': 0, 'The Naked Gun 2½: The Smell of Fear': 0, 'The Manchurian Candidate': 0, 'G.I. Jane': 0, 'Gran Torino': 0, 'Three Kings': 0, 'Harts War': 0, 'Man of the Year': 0, 'xXx: State of the Union': 0, 'Antz': 0, 'The Lucky Ones': 0}
# 0it [00:00, ?it/s]
# rating: 4.0 , movie: The Kite Runner
# rating: 5.0 , movie: The Talented Mr. Ripley
# rating: 3.5 , movie: In Time
# rating: 4.5 , movie: The Karate Kid
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
': 0, 'Disclosure': 0, 'A Million Ways to Die in the West': 0, 'Kiss of Death': 0, 'The Devils Advocate': 0, 'Mad Max: Fury Road': 2.0, 'The Road': 0, 'You Will Meet a Tall Dark Stranger': 1.5, 'Anything Else': 1.5, 'Snow White and the Huntsman': 0, 'Annie Hall': 1.5, 'Everyone Says I Love You': 1.5, 'Everything You Always Wanted to Know About Sex *But Were Afraid to Ask': 1.5, 'You Kill Me': 0, 'Celebrity': 1.5, 'The Good German': 0, 'Confessions of a Dangerous Mind': 0, 'Legal Eagles': 0, 'Radio Days': 1.5, 'Small Time Crooks': 1.5, 'Lucky Numbers': 2.0, 'The Sessions': 0, 'The Yards': 0, 'Blue Jasmine': 1.5, 'Men of Honor': 0, 'Sleeper': 1.5, 'The Adventures of Ford Fairlane': 0, 'Whatever Works': 1.5, 'Scoop': 1.5, 'Sweet November': 0, 'Reindeer Games': 0, 'Midnight in Paris': 1.5, 'As Good as It Gets': 0, 'Deconstructing Harry': 0, 'Inherent Vice': 0, 'The Astronauts Wife': 0, 'A Thin Line Between Love and Hate': 0, 'Pay It Forward': 0, 'Rendition': 2.0, 'Syriana': 1.5, 'A Most Violent Year': 0.5, 'Sphinx': ...
# 0it [00:00, ?it/s]
# rating: 1.5 , movie: Mean Streets
# rating: 0.5 , movie: Y Tu Mamá También
# rating: 4.0 , movie: Rambo III
# rating: 3.0 , movie: Lions for Lambs
# rating: 2.0 , movie: Being John Malkovich
# rating: 4.5 , movie: Confessions of a Dangerous Mind
# rating: 3.5 , movie: Alvin and the Chipmunks
# rating: 4.0 , movie: Shine a Light
# rating: 5.0 , movie: Madagascar
# rating: 3.5 , movie: Star Trek: Generations
# {'Shine a Light': -0.5, 'Casino': 1.0, 'Gangs of New York': 1.0, 'New York, New York': 1.0, 'Shark Tale': -0.5, 'Red Lights': -0.5, 'The Aviator': 1.0, 'Silver Linings Playbook': 1.5, 'Raging Bull': 1.0, 'Meet the Parents': -0.5, 'Brazil': -0.5, 'The Last Waltz': 1.0, 'The Age of Innocence': 1.0, 'Heist': -0.5, 'Cop Land': -0.5, 'Meet the Fockers': -0.5, 'Dirty Grandpa': -0.5, 'Marvins Room': -0.5, 'Hugo': 1.0, 'Shutter Island': 1.0, 'Stardust': -0.5, 'Cape Fear': 1.0, 'The Color of Money': 1.0, 'The Departed': 3.0, 'The Godfather: Part II': -0.5, 'Machete': -0.5, 'Killer Elite': 1.5, 'Godsend': -0.5, 'Kundun': 1.0, 'Bringing Out the Dead': 1.0, 'Stone': -0.5, 'The Bridge of San Luis Rey': -0.5, 'The Last Temptation of Christ': 1.0, 'Taxi Driver': 1.0, 'Amores perros': -0.5, 'Pans Labyrinth': -1, 'The Covenant': 1.0, 'Notes on a Scandal': -1, 'Disturbing Behavior': -1, 'Outside Providence': 1.0, 'Reno 911!: Miami': -1, 'Its Kind of a Funny Story': -1, 'EuroTrip': -1, 'Losin It': -1, 'Magic Mike XXL': -1, 'LOL': 1.0, 'Maurice': -1, 'Porkys': -1, 'Chronicle': -1, 'Fast Times at Ridgemont High': -1, 'Savage Grace': -1, 'The Shallows': -1, 'The Spectacular Now': 1.0, 'Shortbus': 1.0, 'High School Musical 3: Senior Year': 1.0, 'The Way Way Back': -1, 'Dope': 1.0, 'Mambo Italiano': -1, 'American Pie': -1, 'Fish Tank': -1, 'Summer Storm': -1, 'Miss March': -1, 'Just Looking': -1, 'Juliet and Alfa Romeo': -1, 'Sex Drive': -1, 'Not Cool': -1, 'Road Trip': -1, 'Pieces of April': -1, 'Dazed and Confused': -1, 'A Walk to Remember': -1, 'Rambo: First Blood Part II': 2.0, 'Jurassic World': 0.5, '3000 Miles to Graceland': 2.5, 'Mission: Impossible - Ghost Protocol': 0.5, 'Apocalypto': 0.5, 'Knock Off': 0.5, 'The Jackal': 0.5, 'Street Fighter: The Legend of Chun-Li': 0.5, 'Charlies Angels': 2.5, 'Planet of the Apes': 0.5, 'Green Lantern': 0.5, 'X2': 0.5, 'The Spy Who Loved Me': 0.5, 'Lethal Weapon 4': 2.5, 'Anacondas: The Hunt for the Blood Orchid': 0.5, 'Without a Paddle': 0.5, 'G.I. Joe: The Rise of Cobra': 0.5, 'Dick Tracy': 2.5, '300': 0.5, 'Star Trek V: The Final Frontier': 0.5, 'Lara Croft: Tomb Raider': 0.5, 'Tora! Tora! Tora!': 0.5, 'Lucky Numbers': 2.0, 'Lethal Weapon 3': 2.5, 'RED': 2.5, 'Speed 2: Cruise Control': 0.5, 'Bad Boys II': 2.5, 'Broken Arrow': 0.5, 'Serenity': 0.5, 'The Fugitive': 0.5, 'The Matrix Revolutions': 0.5, 'Red Tails': 0.5, 'Spawn': 0.5, 'Sorcerer': 0.5, 'Vertical Limit': 0.5, 'Young Sherlock Holmes': 2.5, 'Star Trek III: The Search for Spock': 0.5, 'Cliffhanger': 0.5, 'RoboCop 3': 0.5, 'The Saint': 0.5, 'Never Say Never Again': 0.5, 'The Big Hit': 0.5, 'A View to a Kill': 0.5, 'Moonraker': 0.5, 'X-Men Origins: Wolverine': 0.5, 'Terminator Genisys': 0.5, 'The Negotiator': 2.5, 'Executive Decision': 0.5, 'Extreme Ops': 0.5, 'Act of Valor': 0.5, 'Alive': 0.5, 'The Last of the Mohicans': 0.5, 'The World Is Not Enough': 0.5, 'The Green Inferno': 0.5, 'The Day After Tomorrow': 0.5, 'The Host': 2.5, 'The Island': 0.5, 'Race to Witch Mountain': 0.5, 'Changing Lanes': 0.5, 'The Core': 0.5, 'The Hunting Party': 0.5, 'Congo': 0.5, 'Daylight': 0.5, 'Maximum Risk': 0.5, 'Bad Company': 3.5, 'The Rock': 0.5, 'The Forsaken': 0.5, 'The Brothers Grimm': 0.5, 'Battleship': 0.5, 'Space Cowboys': 0.5, 'Free State of Jones': 0.5, 'Cirque du Freak: The Vampires Assistant': 0.5, 'Dragonball Evolution': 0.5, 'The Abyss': 0.5, 'Hollywood Homicide': 0.5, 'U-571': 0.5, 'Walking Tall': 0.5, 'The Count of Monte Cristo': 0.5, 'Knowing': 0.5, 'Lara Croft Tomb Raider: The Cradle of Life': 0.5, 'G.I. Joe: Retaliation': 0.5, 'Escape from L.A.': 0.5, 'Mad Max: Fury Road': 0.5, 
11:14': 0, 'Broken Horses': 0, 'The Sentinel': 0, 'Confessions of a Dangerous Mind': 0, 'The Host': 0, 'Green Zone': 0, 'Man on a Ledge': 0, 'In the Valley of Elah': 0, 'Changing Lanes': 0, 'Alex Cross': 0, 'Menace II Society': 0, 'Romeo Must Die': 0, 'The Hunting Party': 0, 'Civil Brand': 0, 'Killer Joe': 0, 'Kiss the Girls': 0, 'L.A. Confidential': 0, 'Fast Five': 0, 'San Andreas': 0, 'The Punisher': 0, 'Along Came a Spider': 0, 'Compliance': 0, 'Congo': 0, 'End of Watch': 0, 'No Country for Old Men': 0, 'Con Air': 0, 'The Way of the Gun': 0, 'We Own the Night': 0, 'Mad City': 0, 'I Am Legend': 0, 'Lakeview Terrace': 0, 'The Bourne Identity': 0, 'High Crimes': 0, 'Code of Honor': 0, 'Death to Smoochy': 0, 'The Spirit': 0, 'Dawn of the Planet of the Apes': 0, 'Alone With Her': 0, 'Jack Ryan: Shadow Recruit': 0, 'Free State of Jones': 0, 'Wild Card': 0, 'Panic Room': 0, 'The Town': 0, 'Lucky Number Slevin': 0, 'The Score': 0, 'The Silence of the Lambs': 0, 'Good Kill': 0, 'U-571': 0, 'The Count of Monte Cristo': 0, 'The Hudsucker Proxy': 0, 'Walking Tall': 0, 'Wicked Blood': 0, 'Gridiron Gang': 0, 'Knowing': 0, '2 Fast 2 Furious': 0, 'Midnight in the Garden of Good and Evil': 0, 'Out of the Furnace': 0, 'Shaft': 0, '21 Grams': 0, 'A Time to Kill': 0, 'Runner Runner': 0, 'Find Me Guilty': 0, 'The Man Who Knew Too Little': 0, 'Prisoners': 0, 'Transporter 2': 0, 'Prison': 0, 'Quantum of Solace': 0, 'Hostage': 0, 'The Grey': 0, 'The Pacifier': 0, 'The G ...
# 0it [00:00, ?it/s]
# rating: 4.5 , movie: U-571
# rating: 3.0 , movie: Kindergarten Cop
# rating: 2.5 , movie: Maurice
# rating: 3.0 , movie: Lions for Lambs
# rating: 1.5 , movie: The Butterfly Effect
# rating: 3.0 , movie: Lawrence of Arabia
# rating: 4.0 , movie: Superman
# rating: 5.0 , movie: Madagascar
# rating: 1.0 , movie: Alexander
# rating: 2.0 , movie: My Super Ex-Girlfriend
# {'Lone Survivor': 0.0, 'Green Zone': 0.5, 'The Last Samurai': -3.5, 'Takers': 0.5, 'Clear and Present Danger': 0.5, 'The Hunted': 0.5, 'Platoon': -1.5, 'Run All Night': 0.5, 'Apocalypto': -1.5, 'Sabotage': 0.5, 'Courage Under Fire': 0.5, 'Faster': 0.5, 'The Bourne Ultimatum': 0.5, 'Breakdown': 0.5, 'Kiss of Death': 0.5, 'Hackers': -1.0, 'Lone Wolf McQuade': -1.5, 'Hitman': 0.5, 'Enemy of the State': 2.0, 'Outbreak': 0.5, 'Salvation Boulevard': 0.5, 'Tears of the Sun': -1.5, 'Armored': 0.5, 'Training Day': 0.5, 'Brooklyn Rules': 0.5, 'Conspiracy Theory': 2.0, '10th & Wolf': 0.5, 'Tora! Tora! Tora!': -1.0, 'The Fast and the Furious: Tokyo Drift': 0.5, 'Scarface': 0.5, 'Swelter': 0.5, 'Point Blank': 0.5, 'Man on Fire': 0.5, 'The Messenger: The Story of Joan of Arc': -1.0, 'Payback': 0.5, 'Broken Arrow': -1.5, 'Firestarter': 0.5, 'Romeo Is Bleeding': 0.5, 'In Her Line of Fire': 0.5, 'The Finest Hours': -1.5, 'Buffalo Soldiers': 0.5, 'Shooter': 0.5, 'Vampires': 0.5, 'The Quiet American': -1.5, 'Red Tails': -1.0, 'Dinner Rush': 0.5, '1941': 1.5, 'The Dark Knight Rises': 4.5, 'Elysium': 0.5, 'Young Sherlock Holmes': -1.5, 'Drive': 0.5, 'Paparazzi': 0.5, 'The Net': 0.5, 'The Hurt Locker': 0.5, 'Sands of Iwo Jima': -1.0, 'Bound by Honor': 0.5, 'The Negotiator': -1.5, 'Executive Decision': -1.5, 'Extreme Ops': -1.5, 'Act of Valor': 0.5, 'Deterrence': 0.5, 'Dead Man Down': 0.5, 'Harper': 0.5, 'Alive': -1.5, 'Ladder 49': 0.5, 'I Am Wrath': 0.5, 'Running Scared': 0.5, 'The Bodyguard': -1.5, 'The Last of the Mohicans': -1.0, 'White House Down': 0.5, 'Patriot Games': 0.5, 'The Host': 1.0, 'K-19: The Widowmaker': 1.5, 'The Patriot': -1.0, 'The Yards': 0.5, 'The Hunting Party': -1.5, 'San Andreas': 0.5, 'Congo': 0.5, 'The Way of the Gun': 0.5, 'The Limey': 0.5, 'Mad City': 0.5, 'I Am Legend': 0.5, 'The Baader Meinhof Complex': -1.5, 'The Bourne Identity': -2.5, 'Colombiana': 0.5, 'Rambo III': -1.5, 'Dawn of the Planet of the Apes': 0.5, 'Jack Ryan: Shadow Recruit': 0.5, 'Rambo: First Blood Part II': -1.5, 'The Matador': 0.5, 'Walking Tall': -1.5, 'Good Kill': 0.5, 'Need for Speed': 0.5, 'The Count of Monte Cristo': -1.5, 'The Longest Day': -1.0, 'Wicked Blood': 0.5, 'Knowing': 0.5, 'Brothers': 0.5, 'Death Sentence': 0.5, 'First Blood': -1.5, 'The Monuments Men': -1.0, 'The Grey': 0.5, 'The Pacifier': 0.5, 'The Good German': -1.5, 'Nowhere to Run': -1.5, 'Alexander': 0.5, 'Get Carter': 0.5, 'Killing Zoe': 0.5, 'Mr. & Mrs. Smith': 0.5, 'Double Impact': 0.5, 'Dark Blue': 0.5, 'Letters to God': 0.5, 'Carriers': 0.5, 'The Charge of the Light Brigade': -3.5, 'The Bourne Supremacy': 0.5, 'Open Road': 0.5, 'Flyboys': -1.0, 'Contraband': 0.5, 'Captain Phillips': 0.5, 'Rise of the Planet of the Apes': 0.5, 'The Last Castle': 0.5, 'In the Heart of the Sea': -3.5, 'Poseidon': -1.5, 'Sugar Hill': 0.5, 'Flight of the Phoenix': -1.5, 'Topaz': 0.5, 'Fury': -1.5, 'Southland Tales': -2.5, 'Windtalkers': -1.0, 'Eraser': 0.5, 'Basic': 0.5, 'Harsh Times': 0.5, 'Gangster Squad': 0.5, 'Saints and Soldiers': -1.0, 'Letters from Iwo Jima': -3.5, 'Proof of Life': -3.5, 'Crimson Tide': 2.0, 'Stake Land': 0.5, 'Braveheart': -1.0, 'Flight of the Intruder': -1.5, 'Jonah Hex': 0.5, '3 Days to Kill': 0.5, 'Collateral Damage': 0.5, 'Children of Men': 0.5, 'World War Z': 0.5, 'The Glimmer Man': -1.5, 'The Death and Life of Bobby Z': 0.5, 'The Great Escape': -1.0, 'Jimmy and Judy': 0.5, 'Valkyrie': -1.5, 'Capricorn One': 0.5, 'Undisputed': -1.5, 'Narc': 0.5, 'Dracula Untold': -1.5, 'Chain Reaction': 0.5, 'Street Kings': 0.5, 'United 93': -1.5, 'xXx: State of the Union': -1.5, 'Echo Dr.': 0.5, 'Mercury Rising': 0.5, 'The Dark Knight': 4.5, 'Two Evil Eyes': 0.5, 'Terminator 3: Rise of the Machines': 0.5, 'Shanghai Calling': 0.5, 'Cry_Wolf': 0.5, 'Tombstone': -1.0, 'Nightcrawler': 0.5, 'The Piano': 0.5, 'Little Nicky': 0.5, 'Cop Land': 0.5, 'Edge of Tomorrow': 0.5, 'Free State of Jones': -1.0, 'From Dusk Till Dawn': 0.5, 'The Devils Double': -1.5, 'Apollo 13': 0.5, 'Vertical Limit ...
# 0it [00:00, ?it/s]
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 4.0 , movie: The French Connection
# rating: 3.5 , movie: Along Came a Spider
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 5.0 , movie: The Forbidden Kingdom
# rating: 3.0 , movie: Mr. Beans Holiday
# rating: 2.0 , movie: Being John Malkovich
# rating: 5.0 , movie: The Wedding Planner
# rating: 1.5 , movie: The Butterfly Effect
# rating: 2.5 , movie: My Best Friends Wedding
# {'Lost in Translation': 0, 'An Education': 0, '3000 Miles to Graceland': 0.5, 'Takers': 0.5, 'The Hunted': 0.5, 'Run All Night': 0.5, 'Kill Bill: Vol. 2': 0.5, 'Sabotage': 0.5, 'The Jackal': 0.5, 'Repo Men': 0.5, 'Faster': 0.5, 'Ninja Assassin': 0.5, 'Charlies Angels': 0.5, 'Kiss of Death': 0.5, 'Whiteout': 0.5, 'Machete Kills': 0.5, 'Hackers': 0.5, 'Lone Wolf McQuade': 0.5, 'Heist': 0.5, 'Hitman': 0.5, 'Stone Cold': 0.5, 'Chicago Overcoat': 0.5, 'Taxman': 0.5, 'The November Man': 0.5, 'Lethal Weapon 4': 0.5, 'Dick Tracy': 0.5, 'Armored': 0.5, 'From Dusk Till Dawn': 0.5, 'The Last Stand': 0.5, 'Training Day': 1.5, 'The Fast and the Furious': 0.5, '10th & Wolf': 0.5, 'Checkmate': 0.5, 'Lucky Numbers': 0.5, 'Lethal Weapon 3': 0.5, 'RED': 0.5, 'The Equalizer': 0.5, 'The Fast and the Furious: Tokyo Drift': 0.5, 'S.W.A.T.': 0.5, 'Scarface': 0.5, 'The Adventures of Ford Fairlane': 0.5, 'Bad Boys II': 0.5, 'The Mechanic': 0.5, 'Point Blank': 0.5, 'Man on Fire': 0.5, 'Payback': 0.5, 'Bad Boys': 0.5, 'Romeo Is Bleeding': 0.5, 'Desperado': 0.5, 'The Fugitive': 0.5, 'Shooter': 0.5, 'The Dark Knight Rises': 0.5, 'Gone in Sixty Seconds': 0.5, 'Snakes on a Plane': 0.5, 'Young Sherlock Holmes': 0.5, 'Drive': 0.5, 'Crank': -1.0, 'RoboCop 3': 0.5, 'Bullet to the Head': 0.5, 'The Boondock Saints II: All Saints Day': 0.5, 'The Net': 0.5, 'Point Break': 0.5, 'Turbulence': 0.5, 'The Transporter': 0.5, 'Bound by Honor': 0.5, 'The Negotiator': 0.5, 'True Romance': 0.5, 'Running Scared': 0.5, 'Dead Man Down': 0.5, 'Harper': 0.5, 'I Am Wrath': 0.5, 'Half Past Dead': 0.5, 'Patriot Games': 0.5, 'The Sentinel': 0.5, 'Man on a Ledge': 0.5, 'Changing Lanes': 0.5, 'Alex Cross': 0.5, 'The Yards': 0.5, 'Romeo Must Die': 0.5, 'Fast Five': 0.5, 'Along Came a Spider': 0.5, 'The Way of the Gun': 0.5, 'Con Air': 0.5, 'The Limey': 0.5, 'Code of Honor': 0.5, 'The Spirit': 0.5, 'The Score': 0.5, 'The Matador': 0.5, 'Need for Speed': 0.5, 'City Hall': 1.5, '2 Fast 2 Furious': 0.5, 'Death Sentence': 0.5, 'Shaft': 0.5, 'The Man Who Knew Too Little': 0.5, 'Transporter 2': 0.5, 'Quantum of Solace': 0.5, 'Get Carter': 0.5, 'Brooklyns Finest': 1.5, 'Taken 2': 0.5, 'Killing Zoe': 0.5, 'Safe': 0.5, 'Double Impact': 0.5, 'Dark Blue': 0.5, 'Smokin Aces': 0.5, 'Into the Blue': 0.5, 'The River Wild': 0.5, 'Assassins': 0.5, 'Contraband': 0.5, 'Pain & Gain': 0.5, 'Ronin': 0.5, 'Face/Off': 0.5, 'Drive Angry': 0.5, 'Shade': 0.5, 'Timecop': 0.5, 'The Boondock Saints': 0.5, 'Crank: High Voltage': -1.0, 'Kiss of the Dragon': 0.5, 'Confidence': 0.5, 'Cellular': 0.5, 'Straight Outta Compton': 1.5, 'Wanted': 0.5, 'London Has Fallen': 0.5, 'Basic': 0.5, 'Harsh Times': 0.5, 'Gangster Squad': 0.5, 'Nighthawks': 0.5, '16 Blocks': 0.5, '3 Days to Kill': 0.5, 'The Long Kiss Goodnight': 0.5, 'The Glimmer Man': 0.5, 'The Death and Life of Bobby Z': 0.5, 'Jimmy and Judy': 0.5, 'Narc': 0.5, 'The Losers': 0.5, 'Sin City': 0.5, 'Street Kings': 0.5, 'United 93': 0.5, 'xXx: State of the Union': 0.5, 'Black Rain': 0.5, 'Mercury Rising': 0.5, 'RED 2': 0.5, 'Virtuosity': 0.5, 'The Dark Knight': 0.5, 'Killer Joe': 0.5, 'Jade': 0.5, 'Sorcerer': 0.5, 'The Punisher': 0.5, 'Layer Cake': 0.5, 'Elite Squad': 0.5, 'Traffic': 0.5, 'Open Secret': 0, 'Mindhunters': 0, 'Slow Burn': 0, 'Pandorum': 0, 'Edge of Darkness': 0, 'Insomnia': 0, 'All Good Things': 0, 'Mystic River': 0, 'The Raven': 0, 'Disclosure': 0, 'The Bourne Ultimatum': 0, 'The Girl with the Dragon Tattoo': 0, 'Transsiberian': 0, 'Conspiracy Theory': 0, 'Non-Stop': 0, 'Class of 1984': 0, 'Dylan Dog: Dead of Night': 0, 'The Client': 0, 'Basic Instinct 2': 0, 'Brigham City': 0, 'Salt': 0, 'Abduction': 0, 'Blood Work': 0, 'The Betrayed': 0, 'Zero Effect': 0, 'Domestic Disturbance': 0, 'The Dead Girl': 0, 'The Jacket': 0, 'Sherlock Holmes: A Game of Shadows': 0, 'Deterrence': 0, 'Body Double': 0, 'Broken Horses': 0, 'In the Valley of Elah': 0, 'Kiss the Girls': 0, 'Subconscious': 0, 'L.A. Confidential': 0, 'Congo': 0, 'The Baader Meinhof Complex': 0, 'High Cr ...
# 0it [00:00, ?it/s]
# rating: 4.5 , movie: The Karate Kid
# rating: 1.0 , movie: Notting Hill
# rating: 4.0 , movie: Stand by Me
# rating: 2.0 , movie: About Schmidt
# rating: 0.5 , movie: Live and Let Die
# rating: 4.0 , movie: Cinderella Man
# rating: 4.0 , movie: Pandoras Box
# rating: 5.0 , movie: The Forbidden Kingdom
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
# rating: 0.5 , movie: Y Tu Mamá También
# {'Rocky': 2.0, 'Dude, Where’s My Car?': 1.5, 'Walking and Talking': -0.5, 'The Broken Hearts Club: A Romantic Comedy': -0.5, 'Crossroads': -0.5, 'Buffalo 66': -0.5, 'Hope Springs': -0.5, 'New York Stories': -0.5, 'Wristcutters: A Love Story': -0.5, 'Quartet': -0.5, 'Anywhere But Here': -0.5, 'Varsity Blues': -0.5, 'Shopgirl': -0.5, 'Rock of Ages': -0.5, 'Chocolat': -0.5, 'The Wendell Baker Story': -0.5, 'The Last Five Years': -0.5, 'Hannah Montana: The Movie': -0.5, 'Maid in Manhattan': -0.5, 'Kiss the Bride': -0.5, 'Riding in Cars with Boys': -0.5, 'How Do You Know': -0.5, 'Forrest Gump': 2.5, 'Molly': -0.5, 'Morning Glory': -0.5, 'A Good Year': -0.5, 'Double Take': -0.5, 'The Apartment': -0.5, 'Tadpole': -0.5, 'High School Musical 3: Senior Year': -1.5, 'Living Out Loud': -0.5, 'Tiny Furniture': -0.5, 'Boys and Girls': -1.5, 'The Sessions': -0.5, 'About a Boy': -1.5, 'Shes the Man': -0.5, 'The Talented Mr. Ripley': -4.5, 'Cheri': -0.5, 'Crazy, Stupid, Love.': -0.5, 'Love & Other Drugs': -0.5, 'Bubble Boy': -0.5, 'Cant Hardly Wait': -0.5, 'Four Christmases': -0.5, 'Away We Go': -0.5, 'The Family Stone': -0.5, 'Letters to Juliet': -0.5, 'Andersons Cross': -0.5, 'Inherent Vice': -0.5, 'Meet Dave': -1.5, 'The Proposal': -0.5, 'Peggy Sue Got Married': -0.5, 'Tin Cup': -0.5, 'Outside Providence': -1.5, 'The Mirror Has Two Faces': -0.5, 'The Four Seasons': -0.5, 'The Rules of Attraction': -0.5, 'Madeas Family Reunion': -0.5, 'Big': -0.5, 'Chasing Amy': -0.5, 'Bend It Like Beckham': -0.5, 'Bridget Joness Diary': -7.5, 'Juno': -0.5, 'LOL': -1.5, 'Admission': -0.5, 'Drumline': -0.5, 'Divine Secrets of the Ya-Ya Sisterhood': -0.5, 'You Will Meet a Tall Dark Stranger': -0.5, 'What Planet Are You From?': -0.5, 'Full Frontal': -0.5, '(500) Days of Summer': -0.5, '10 Things I Hate About You': -0.5, 'Where the Heart Is': -0.5, 'Don Jon': -0.5, 'Good Luck Chuck': -0.5, 'Confessions of a Dangerous Mind': -0.5, 'Barry Munday': -0.5, 'Good Dick': -0.5, 'Love Jones': -0.5, 'The Front Page': -0.5, 'The Spectacular Now': -1.5, 'How to Deal': -0.5, 'The Brothers': -0.5, 'Lovely & Amazing': -0.5, 'Everything Must Go': -0.5, 'Loser': -0.5, 'Youth in Revolt': 2.5, 'When Harry Met Sally...': 1.0, 'The Perez Family': -0.5, 'Lars and the Real Girl': -0.5, 'School for Scoundrels': -0.5, 'Ever After: A Cinderella Story': -0.5, 'Return to Me': -0.5, 'The Incredibly True Adventure of Two Girls In Love': -0.5, 'A Mighty Heart': -1.5, 'Cyrus': -0.5, 'Drive Me Crazy': -0.5, 'American Desi': -0.5, 'My Beautiful Laundrette': -0.5, 'The Good Night': -0.5, 'My Last Day Without You': -0.5, 'Beginners': -0.5, 'Hitch': -0.5, 'Stranger Than Fiction': -0.5, 'Focus': -0.5, 'Dear Wendy': 2.5, 'Jesus Son': -0.5, 'Going the Distance': -0.5, 'Joe Dirt': -0.5, 'Larry Crowne': -0.5, 'Man on the Moon': -0.5, 'Love Actually': -1.5, 'Sweet Charity': -0.5, 'The Brothers Bloom': -0.5, 'In Good Company': -0.5, 'Jerry Maguire': 1.0, 'The Brothers McMullen': -0.5, 'Don Juan DeMarco': -0.5, 'Raising Helen': -0.5, 'The Wood': -0.5, 'Just My Luck': -0.5, 'Little Black Book': -0.5, 'Me and Orson Welles': -0.5, 'How Stella Got Her Groove Back': -0.5, 'Shall We Dance?': -0.5, 'The Battle of Shaker Heights': -0.5, 'The Muppet Movie': -1.5, 'Enough Said': -0.5, 'Trust the Man': -0.5, 'Take Me Home Tonight': -0.5, 'An Ideal Husband': -0.5, 'Down to You': -0.5, 'I Love You Phillip Morris': -0.5, 'Trainspotting': -6.5, 'The American President': 1.0, 'Imagine Me & You': -0.5, 'Sex and the City 2': -0.5, 'Josie and the Pussycats': -1.5, 'Mystic Pizza': -0.5, 'Latter Days': -0.5, 'And So It Goes': 1.0, 'Elizabethtown': -0.5, 'Click': -0.5, 'Fever Pitch': -0.5, 'Friends with Money': -0.5, 'Forgetting Sarah Marshall': -0.5, 'Submarine': -0.5, 'The Good Girl': -0.5, 'Groundhog Day': -0.5, 'Signed, Sealed, Delivered': -0.5, 'Moonrise Kingdom': -0.5, 'Knocked Up': -0.5, 'Safety Not Guaranteed': -0.5, 'How to Lose Friends & Alienate People': -0.5, 'The Good Heart': -0.5, 'Silver Linings Playbook': 2.5, ' ...
# 0it [00:00, ?it/s]
# rating: 4.0 , movie: Cinderella Man
# rating: 5.0 , movie: Madagascar
# rating: 2.5 , movie: My Best Friends Wedding
# rating: 5.0 , movie: The Wedding Planner
# rating: 2.0 , movie: The Sixth Sense
# rating: 0.5 , movie: Y Tu Mamá También
# rating: 3.0 , movie: Lions for Lambs
# rating: 0.5 , movie: Amadeus
# rating: 2.0 , movie: About Schmidt
# rating: 5.0 , movie: The Talented Mr. Ripley
# {'The Hurricane': 2.0, 'Mulan': 1.5, 'Soul Surfer': 1.5, 'For Love of the Game': 1.5, 'Kama Sutra - A Tale of Love': 0.5, 'Eddie the Eagle': 1.5, 'The Scarlet Letter': 0.5, 'The Wrestler': 1.5, 'Joyeux Noël': -3.5, 'Against the Ropes': 1.5, 'The Young Victoria': 0.5, 'The Last of the Mohicans': 0.5, 'Pompeii': 0.5, 'The Express': 1.5, 'My All American': 1.5, 'Alexander': 0.5, 'Cleopatra': 0.5, 'Pulp Fiction': 1.5, 'Any Given Sunday': 1.5, 'Quo Vadis': 0.5, 'Solomon and Sheba': 0.5, 'Stick It': 1.5, 'The Best Years of Our Lives': 0.5, 'Anna and the King': 0.5, 'Memoirs of a Geisha': 0.5, 'The Hammer': 1.5, 'Freedom Writers': 1.5, 'The New World': 0.5, 'Bloodsport': 1.5, 'Radio': 1.5, 'The White Countess': 0.5, 'Captain Corellis Mandolin': 0.5, 'Never Back Down': 1.5, 'Flyboys': 0.5, 'In the Heart of the Sea': 0.5, 'A Beautiful Mind': 0.5, 'Big Mommas House': 0.5, 'Shark Tale': 0.5, 'Turbo': 0.5, 'The Illusionist': 0.5, 'Duplicity': 0.5, 'Jerry Maguire': 0.5, 'Raging Bull': 0.5, 'Cold Mountain': 3.5, 'Splash': 0.5, 'Scary Movie 4': 0.5, 'Dickie Roberts: Former Child Star': 0.5, 'Appaloosa': 0.5, 'The Last Station': 0.5, 'Rush': 0.5, 'Safe Men': 0.5, 'One True Thing': 0.5, 'Angels & Demons': 0.5, 'Edtv': 0.5, 'Duets': 0.5, 'Miss Potter': 0.5, 'Bee Movie': 0.5, 'Leatherheads': 0.5, 'Big Fat Liar': 0.5, 'Saving Mr. Banks': 0.5, 'Ali': 0.5, 'The Dilemma': 0.5, 'The Long Kiss Goodnight': 0.5, 'Apollo 13': 0.5, 'The Ides of March': 0.5, 'How the Grinch Stole Christmas': 0.5, 'Rocky': 0.5, 'Paycheck': 0.5, 'All Is Bright': 0.5, 'The Ant Bully': 0.5, 'Frost/Nixon': 0.5, 'Me, Myself & Irene': 0.5, 'Ransom': 0.5, 'Million Dollar Baby': 0.5, 'The Da Vinci Code': 0.5, 'Rocky Balboa': 0.5, 'Race': 0.5, '24 7: Twenty Four Seven': 0.5, '42': 0.5, 'Snake Eyes': 0.5, 'Unbroken': 0.5, 'Spanglish': 0.5, 'The Black Stallion': 0.5, 'Madagascar: Escape 2 Africa': 4, 'Roar': 3, 'The Nutty Professor': 1, 'Bamboozled': 1, 'Bad Company': 1, 'Tales from the Crypt: Demon Knight': 1, 'A Low Down Dirty Shame': 1, 'Antz': 1, 'Menace II Society': 1, 'Reign Over Me': 1, 'Six Days Seven Nights': 1, 'The Longest Yard': 1, 'Grown Ups 2': 1, 'Penguins of Madagascar': 1, 'Madagascar 3: Europes Most Wanted': 1, 'Shes the One': 6, 'The Guru': 0, 'Crossroads': 0, 'Closer': 3, 'License to Wed': 0, 'In the Name of the King: A Dungeon Siege
, 'The Fast and the Furious': 0.5, '10th & Wolf': 4.5, 'Checkmate': 0.5, 'Lucky Numbers': 0.5, 'Lethal Weapon 3': 0.5, 'RED': 0.5, 'The Equalizer': 0.5, 'The Fast and the Furious: Tokyo Drift': 5.5, 'S.W.A.T.': 0.5, 'Scarface': 4.5, 'The Adventures of Ford Fairlane': 0.5, 'Bad Boys II': 0.5, 'The Mechanic': 0.5, 'Point Blank': 4.5, 'Man on Fire': 8.5, 'Payback': 4.5, 'Bad Boys': 0.5, 'Romeo Is Bleeding': 8.5, 'Desperado': 0.5, 'The Transporter Refueled': 0.5, 'The Fugitive': 0.5, 'Shooter': 4.5, 'The Dark Knight Rises': 4.5, 'Gone in Sixty Seconds': 0.5, 'Snakes on a Plane': 0.5, 'Young Sherlock Holmes': 4.5, 'Drive': 4.5, 'Crank': -1.0, 'RoboCop 3': 0.5, 'Bullet to the Head': 0.5, 'The Boondock Saints II: All Saints Day': 0.5, 'The Net': 4.5, 'Point Break': 0.5, 'Turbulence': 0.5, 'Bound by Honor': 4.5, 'The Negotiator': 4.5, 'True Romance': 0.5, 'Running Scared': 4.5, 'Dead Man Down': 4.5, 'Harper': 4.5, 'I Am Wrath': 4.5, 'Half Past Dead': 0.5, 'Patriot Games': 4.5, 'The Sentinel': 0.5, 'Man on a Ledge': 0.5, 'Changing Lanes': 0.5, 'Alex Cross': 0.5, 'The Yards': 4.5, 'Romeo Must Die': 0.5, 'Fast Five': 0.5, 'Along Came a Spider': 0.5, 'The Way of the Gun': 4.5, 'Con Air': 0.5, 'The Limey': 4.5, 'The Baader Meinhof Complex': 4.5, 'Code of Honor': 0.5, 'Colombiana': 4.5, 'The Spirit': 0.5, 'Cars': 1.5, 'The Score': 0.5, 'The Matador': 4.5, 'Need for Speed': 8.5, '2 Fast 2 Furious': 0.5, 'Death Sentence': 4.5, 'Shaft': 0.5, 'The Man Who Knew Too Little': 0.5, 'Transporter 2': 0.5, 'Quantum of Solace': 0.5, 'Get Carter': 4.5, 'Taken 2': 0.5, 'Killing Zoe': 8.5, 'Austin Powers in Goldmember': 1.5, 'Safe': 0.5, 'Double Impact': 4.5, 'Dark Blue': 8.5, 'Smokin Aces': 0.5, 'Into the Blue': 0.5, 'The River Wild': 0.5, 'Assassins': 0.5, 'Contraband': 8.5, 'Pain & Gain': 0.5, 'Ronin': 0.5, 'Face/Off': 0.5, 'Drive Angry': 0.5, 'Shade': 0.5, 'Timecop': 0.5, 'The Boondock Saints': 0.5, 'Crank: High Voltage': -1.0, 'Kiss of the Dragon': 0.5, 'Confidence': 0.5, 'Cellular': 0.5, 'Wanted': 0.5, 'London Has Fallen': 0.5, 'Basic': 4.5, 'Harsh Times': 4.5, 'Gangster Squad': 4.5, 'Nighthawks': 0.5, '16 Blocks': 0.5, '3 Days to Kill': 8.5, 'The Long Kiss Goodnight': 0.5, 'The Glimmer Man': 4.5, 'The Death and Life of Bobby Z': 4.5, 'Jimmy and Judy': 4.5, 'Narc': 4.5, 'The Losers': 0.5, 'Sin City': 0.5, 'Street Kings': 4.5, 'United 93': 8.5, 'xXx: State of the Union': 4.5, 'The French Connection': 0.5, 'Black Rain': 0.5, 'Mercury Rising': 4.5, 'RED 2': 0.5, 'Virtuosity': 0.5, 'The Dark Knight': 8.5, 'Unleashed': 0.5, 'Clash of the Titans': 0.5, 'Austin Powers: The Spy Who Shagged Me': 0.5, 'West Side Story': 0, '10 Things I Hate About You': 0, 'Pocahontas': 0, 'Terminator 3: Rise of the Machines': 0, 'Spun': 0, 'The Rainmaker': 4, 'Shopgirl': 0, 'Whats the Worst That Could Happen?': 0, 'Me and Orson Welles': 0, 'The Infiltrator': 4, 'Ice Age: The Meltdown': 0, 'Ice Age: Dawn of the Dinosaurs': 0, 'Titan A.E.': 0, 'Executive Decision': 0, 'One for the Money': 0, 'The Best Man Holiday': 0, 'The Happening': 0, 'Igby Goes Down': 0, 'Ride Along': 0, 'Land of the Dead': 0, 'The Fan': 0, 'Australia': 0, 'Ice Age': 0, 'The Best Man': 0, 'The Great Gatsby': 0, 'Spawn': 0, 'The Edge': 0, 'Super Mario Bros.': 0, 'Pans Labyrinth': -1, 'The Covenant': -1, 'Notes on a Scandal': 2, 'Disturbing Behavior': -1, 'Outside Providence': -2.5, 'Reno 911!: Miami': -1, 'Its Kind of a Funny Story': -1, 'EuroT ...
# precision: 0.4576867688554994
# recall: 0.09305555555555553
# f1: 0.1503222910878152

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 50)
    print(movie_score)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# rating: 3.5 , movie: Titanic
# rating: 4.0 , movie: Flash Gordon
# rating: 2.5 , movie: Along Came Polly
# rating: 5.0 , movie: Hannibal Rising
# rating: 2.0 , movie: Wasabi
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 3.5 , movie: In Time
# rating: 4.0 , movie: Superman
# rating: 2.5 , movie: My Best Friends Wedding
# rating: 2.0 , movie: The Last Emperor
# rating: 3.5 , movie: To Kill a Mockingbird
# rating: 4.0 , movie: The French Connection
# rating: 5.0 , movie: Space Jam
# rating: 4.5 , movie: The Island
# rating: 3.0 , movie: The Curse of the Jade Scorpion
# rating: 4.5 , movie: U-571
# rating: 5.0 , movie: Men in Black II
# rating: 1.0 , movie: Notting Hill
# rating: 4.5 , movie: Mission: Impossible
# rating: 3.0 , movie: Manderlay
# rating: 3.5 , movie: Along Came a Spider
# rating: 4.0 , movie: Deconstructing Harry
# rating: 5.0 , movie: Letters from Iwo Jima
# rating: 5.0 , movie: Terminator 3: Rise of the Machines
# rating: 3.0 , movie: Friends with Money
# rating: 3.5 , movie: Open Season
# rating: 1.0 , movie: Rocky Balboa
# rating: 3.5 , movie: Aliens vs Predator: Requiem
# rating: 4.5 , movie: Charlie Wilsons War
# rating: 5.0 , movie: The First Wives Club
# rating: 3.0 , movie: Gothika
# rating: 5.0 , movie: Solaris
# rating: 3.0 , movie: Wag the Dog
# rating: 4.0 , movie: This Is 40
# rating: 2.5 , movie: Romeo + Juliet
# rating: 0.5 , movie: Live and Let Die
# rating: 5.0 , movie: Escape from New York
# rating: 3.0 , movie: Spellbound
# rating: 0.5 , movie: Amadeus
# rating: 2.5 , movie: Maurice
# rating: 4.0 , movie: Cinderella Man
# rating: 4.5 , movie: Match Point
# rating: 3.0 , movie: Jekyll and Hyde ... Together Again
# rating: 5.0 , movie: The Wedding Planner
# rating: 3.0 , movie: Bill & Teds Bogus Journey
# rating: 2.0 , movie: About Schmidt
# rating: 4.0 , movie: Stand by Me
# rating: 1.0 , movie: Under Siege 2: Dark Territory
# rating:
go with It': 0, 'The Iron Giant': 9.0, 'Lucky You': 0, 'Friends with Money': -2.0, 'Punch-Drunk Love': -2.0, 'Marley & Me': 0, 'Zulu': 1, 'The Life of David Gale': 3.0, 'Red Riding: In the Year of Our Lord 1974': 3.0, 'The Godfather: Part III': 6.0, 'Edge of Darkness': 3.0, 'The Proposition': -1.0, 'Trance': 3.0, 'Need for Speed': 7.0, 'Deadfall': 3.0, 'Harry Brown': 3.0, 'The Bank Job': 3.0, 'The International': 3.0, 'The Infiltrator': 3.0, 'The Counselor': 3.0, 'Blood and Wine': 4.5, 'Only God Forgives': 3.0, 'Hitman': 7.0, 'Frenzy': 3.0, 'The First Great Train Robbery': 3.0, 'Dead Mans Shoes': 3.0, 'Trash': 3.0, 'Donkey Punch': 3.0, 'London to Brighton': 3.0, 'Owning Mahowny': 3.0, 'Freeze Frame': 3.0, 'Sexy Beast': 3.0, 'Killing Zoe': 13.0, 'The Crying Game': 2.5, 'The Good Thief': 3.0, 'Machine Gun McCain': 1, '3 Days to Kill': 7.0, 'The American': 3.0, 'Dark Blue': 7.0, 'Brother': 3.0, 'Man on Fire': 7.0, 'Layer Cake': -2.0, 'Romeo Is Bleeding': 7.0, 'Buffalo Soldiers': 5.0, 'Frailty': 6.0, 'United 93': 7.0, 'Veronica Guerin': 3.0, 'The Baader Meinhof Complex': 3.0, 'Death to Smoochy': 3.0, 'Brighton Rock': 3.0, 'Colombiana': 3.0, 'Contraband': 7.0, 'Butterfly on a Wheel': 3.0, 'The Dark Knight': 11.0, 'Girl with a Pearl Earring': 1, '28 Days': 1, 'The Silence of the Lambs': 3.0, 'Memoirs of a Geisha': 3.0, '300': 5, 'The Dark Hours': 1, 'Red Dragon': 2.5, 'The Texas Chainsaw Ma ...
# 0it [00:00, ?it/s]
# rating: 2.0 , movie: Wasabi
# rating: 5.0 , movie: The Talented Mr. Ripley
# rating: 3.0 , movie: Kindergarten Cop
# rating: 4.0 , movie: Harry Potter and the Philosophers Stone
# rating: 4.0 , movie: Horrible Bosses
# rating: 5.0 , movie: Madagascar
# rating: 2.0 , movie: The Last Emperor
# rating: 1.0 , movie: Notting Hill
# rating: 4.0 , movie: Barry Lyndon
# rating: 0.5 , movie: Rebecca
# rating: 4.0 , movie: The French Connection
# rating: 2.5 , movie: Rosemarys Baby
# rating: 4.0 , movie: Stand by Me
# rating: 2.0 , movie: Being John Malkovich
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 2.5 , movie: Along Came Polly
# rating: 5.0 , movie: Escape from New York
# rating: 4.5 , movie: Charlie Wilsons War
# rating: 2.0 , movie: About Schmidt
# rating: 3.5 , movie: Aliens vs Predator: Requiem
# rating: 3.0 , movie: Flashdance
# rating: 4.5 , movie: The Karate Kid
# rating: 1.0 , movie: Under Siege 2: Dark Territory
# rating: 3.0 , movie: Psycho
# rating: 3.0 , movie: Jekyll and Hyde ... Together Again
# rating: 5.0 , movie: Dances with Wolves
# rating: 5.0 , movie: The Forbidden Kingdom
# rating: 5.0 , movie: Hannibal Rising
# rating: 2.5 , movie: My Best Friends Wedding
# rating: 3.0 , movie: The Curse of the Jade Scorpion
# rating: 4.0 , movie: Cinderella Man
# rating: 2.0 , movie: Dragonslayer
# rating: 3.0 , movie: Manderlay
# rating: 2.0 , movie: Moulin Rouge!
# rating: 4.0 , movie: Dear Frankie
# rating: 4.0 , movie: Deconstructing Harry
# rating: 2.0 , movie: My Super Ex-Girlfriend
# rating: 3.5 , movie: Along Came a Spider
# rating: 3.0 , movie: Spellbound
# rating: 4.5 , movie: Mission: Impossible
# rating: 3.5 , movie: Titanic
# rating: 5.0 , movie: The Wedding Planner
# rating: 5.0 , movie: Space Jam
# rating: 2.5 , movie: Freddy vs. Jason
# rating: 5.0 , movie: Solaris
# rating: 3.5 , movie: License to Wed
# rating: 3.5 , movie: To Kill a Mockingbird
# rating: 2.0 , movie: Payback
# rating: 1.0 , movie: Alexander
# rating: 5.0 , movie: Men in Black II
# {'Everyone Says I Love You': 5.5, 'Murder by Numbers': 1, 'Takers': 3.0, 'Bridesmaids': 3, 'The Hunted': 3.0, 'New York Stories': 1.0, 'Run All Night': 3.0, 'Slow Burn': 1, 'Edge of Darkness': 5, 'Tarnation': 3, 'All Good Things': 1, 'Niagara': 1, 'One Missed Call': 3, 'Sabotage': 3.0, 'Mystic River': 1, 'Deadfall': 5, 'The Rainmaker': 2.5, 'Amadeus': 3, 'Disclosure': 1, 'Faster': 3.0, 'Out of Time': 1, 'The Bourne Ultimatum': 6.0, 'The Girl with the Dragon Tattoo': 1, 'Savages': -0.5, 'Kiss of Death': 3.0, 'Hackers': 1.5, 'Lone Wolf McQuade': 1.0, 'Hitman': 7.0, 'The Exorcism of Emily Rose': 1, 'Armored': 3.0, 'The Apartment': 1.0, 'Training Day': 4.0, '10th & Wolf': 3.0, 'The Fast and the Furious: Tokyo Drift': 3.0, 'Boys and Girls': 0.0, 'Men in Black': 14.0, 'Scarface': 4.5, 'The American': 5, 'The Devils Own': 1, 'Point Blank': 3.0, 'Man on Fire': 7.0, 'Broken City': 1, 'Notting Hill': 3, 'Payback': 3.0, 'No Reservations': 3, 'Sleepers': 1, 'The Son of No One': 1, 'Romeo Is Bleeding': 7.0, 'Toy Story 2': 7, 'Pride and Glory': 2.5, 'The Client': 1, 'The Flintstones': 7, 'Buffalo Soldiers': 5, 'Frailty': 8, 'Shooter': 3.0, 'Jack Reacher': 1, 'As Good as It Gets': 3, 'The Dark Knight Rises': 6.0, 'Brigham City': 1, 'Butterfly on a Wheel': 5, 'The Lincoln Lawyer': 1, 'Drive': 3.0, 'Young Sherlock Holmes': 3.0, 'Blood Work': 1, 'The Godfather: Part III': 7, 'The Betrayed': 1, 'A History of Violence': 3, 'Albino Alligator': 1, 'Milk': 3, 'Inside Man': 1, 'The Killer Inside Me': 1, 'Bless the Child': 1, 'The Net': 3.0, 'The Bank Job': 5, 'Gattaca': 3, 'The Counselor': 5, 'Bruce Almighty': 3, 'Blood and Wine': 6.5, 'Only God Forgives': 5, 'The Dead Girl': 2.0, 'Bound by Honor': 3.0, 'The Iceman': 1, 'The Merchant of Venice': 3, 'The Negotiator': 3.0, 'The Wizard of Oz': 5.0, 'Running Scared': 3.0, 'Dead Man Down': 3.0, 'Criminal Activities': 1, 'Harper': 3.0, 'Love in the Time of Cholera': 4.0, 'I Am Wrath': 3.0, 'Batman & Robin': 3, 'Married Life': 3, 'Striptease': 1, 'Titanic': 3, 'Patriot Games': 3.0, 'Law Abiding Citizen': 1, '11:14': 1, 'Broken Horses': 1, 'Confessions of a Dangerous Mind': -1.0, 'TMNT': 7, 'Toy Story': 7, 'In the Valley of Elah': 1, 'The Yards': 3.0, 'Civil Brand': 1, 'Killer Joe': 2.5, 'Kiss the Girls': 1, 'L.A. Confidential': 1, 'When Harry Met Sally...': 4.0, 'Compliance': 1, 'End of Watch': 1, 'No Country for Old Men': 1, 'The Way of the Gun': 3.0, 'Men in Black II': 6.0, 'The Limey': 3.0, 'A Mighty Heart': 0.0, 'We Own the Night': 1, 'Lakeview Terrace': 1, 'Sex Drive': 3, 'High Crimes': -5, 'Death to Smoochy': 5, 'Alone With Her': 1, 'Wild Card': 4, 'Panic Room': 1, 'The Town': 1, 'Lucky Number Slevin': 1, 'The Matador': 3.0, 'The Silence of the Lambs': -2, 'Need for Speed': 7.0, 'Midnight in the Garden of Good and Evil': 1, 'Out of the Furnace': 1, 'Death Sentence': 3.0, '21 Grams': 7, 'A Time to Kill': 1, 'Runner Runner': 1, 'Prisoners': 1, 'Prison': 1, 'The Dark Knight': 7.0, 'Hostage': 7, 'The Good German': -1.0, 'Absolute Power': 1, 'A Walk Among the Tombstones': 1, 'Get Carter': 3.0, 'Brooklyns Finest': 4.0, 'The Last House on the Left': 1, 'Down to You': 5.0, 'Killing Zoe': 13.0, 'The Next Three Days': 5, 'The Crying Game': 7, 'Contagion': 1, 'The Pledge': 1, 'Double Impact': 3.0, 'Dark Blue': 7.0, 'Brother': 5, 'Trust': 1, 'Boiler Room': 1, 'Double Jeopardy': 1, 'Match Point': 8.0, 'Envy': 3, 'Clay Pigeons': 1, 'Side Effects': 1, 'The Skeleton Twins': 3, 'Bound': 5, 'Top Gun': 1.0, 'Veronica Guerin': 5, 'Contraband': 7.0, 'The Generals Daughter': 1, 'Poseidon': 4.0, 'The Midnight Meat Train': 1, 'The Life of David Gale': 5, 'Summer of Sam': 1, 'The International': 5, 'Gods and Monsters': 3, 'Gremlins 2: The New Batch': 3, 'Kansas City': 1, 'Zodiac': 1, 'Nightcrawler': 1, 'Nine Dead': 1, 'Basic': 3.0, 'Batman': 16.0, 'Harsh Times': 3.0, 'On Her Majestys Secret Service': 11.0, 'The Bone Collector': -0.5, 'The Taking of Pelham 1 2 3': 1, 'Total Recall': 13, 'Gangster Squad': 3.0, 'The Spanish Pris ...
# 0it [00:00, ?it/s]
# rating: 5.0 , movie: Dances with Wolves
# rating: 3.0 , movie: Bill & Teds Bogus Journey
# rating: 2.0 , movie: Payback
# rating: 3.0 , movie: Spellbound
# rating: 4.0 , movie: Shopgirl
# rating: 3.5 , movie: License to Wed
# rating: 2.5 , movie: My Best Friends Wedding
# rating: 1.5 , movie: The Butterfly Effect
# rating: 5.0 , movie: Terminator 3: Rise of the Machines
# rating: 5.0 , movie: Madagascar
# rating: 2.5 , movie: Romeo + Juliet
# rating: 3.0 , movie: Seven Samurai
# rating: 4.0 , movie: Superman
# rating: 4.5 , movie: The Island
# rating: 1.0 , movie: Rocky Balboa
# rating: 3.0 , movie: Lions for Lambs
# rating: 5.0 , movie: Men in Black II
# rating: 4.0 , movie: This Is 40
# rating: 1.0 , movie: Notting Hill
# rating: 4.0 , movie: Harry Potter and the Philosophers Stone
# rating: 3.0 , movie: Jekyll and Hyde ... Together Again
# rating: 5.0 , movie: A Woman, a Gun and a Noodle Shop
# rating: 5.0 , movie: Hannibal Rising
# rating: 1.0 , movie: Alexander
# rating: 1.5 , movie: Mean Streets
# rating: 3.0 , movie: Psycho
# rating: 2.5 , movie: Freddy vs. Jason
# rating: 3.5 , movie: Titanic
# rating: 4.0 , movie: Flash Gordon
# rating: 3.0 , movie: Manderlay
# rating: 0.5 , movie: Rebecca
# rating: 4.0 , movie: Horrible Bosses
# rating: 4.5 , movie: U-571
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 4.0 , movie: Barry Lyndon
# rating: 4.0 , movie: The Kite Runner
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 4.0 , movie: Stand by Me
# rating: 4.5 , movie: The Karate Kid
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 3.0 , movie: The Curse of the Jade Scorpion
# rating: 3.5 , movie: Aliens vs Predator: Requiem
# rating: 4.0 , movie: The French Connection
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
# rating: 2.0 , movie: Notes on a Scandal
# rating: 4.5 , movie: Team America: World Police
# rating: 3.0 , movie: Gothika
# rating: 2.5 , movie: Maurice
# rating: 5.0 , movie: Solaris
# {'Quigley Down Under': -0.5, 'The Proposition': 3.0, 'Girl, Interrupted': 1.5, 'Cold Mountain': 3, 'True Grit': 1, 'Tombstone': 1.0, 'The Revenant': 3, 'The Timber': 1, '21 Grams': 3, 'Young Guns': -1.0, 'Anna Karenina': 3, 'Dead Man Walking': 3, 'Magnolia': 3, 'The Homesman': 3, 'The Fisher King': 3, 'The Three Burials of Melquiades Estrada': 1, 'The Great Escape': 6.5, 'Shanghai Noon': 7, 'In Dreams': -3, 'Pocahontas': 3, 'Swimming Pool': 1, 'Doctor Zhivago': 1.0, 'John Carter': 11.0, 'Finding Forrester': 6.0, 'Its a Wonderful Life': 3, 'The Last Samurai': -1.0, 'Die Hard: With a Vengeance': 1, 'Open Range': 1, 'Independence Day': 9.0, 'Unnatural': 1, 'The Postman': 1, 'Lost in Translation': 1, '2046': 1, 'Bill & Teds Excellent Adventure': 4, 'Star Wars: Clone Wars: Volume 1': 7.5, 'Percy Jackson & the Olympians: The Lightning Thief': 2.0, 'Crossroads': 2.5, 'Premonition': 0, 'Land of the Lost': 4, 'What Dreams May Come': 1.5, 'Minions': 0, 'Kung Fu Panda 3': 2.5, 'Yogi Bear': 0, 'Black Knight': 0, 'Inkheart': 2.0, 'Rio': 1.5, 'Home Alone 2: Lost in New York': 1.5, 'Down to Earth': 0, 'Beverly Hills Chihuahua': 0, 'Monster House': 0, 'Troop Beverly Hills': 0, 'Jupiter Ascending': 10.0, 'Tomorrowland': 0, 'The Haunted Mansion': 0, 'The Smurfs 2': 0, 'Alvin and the Chipmunks: Chipwrecked': 0, 'Penguins of Madagascar': 3, 'Looper': 6.0, 'The Indian in the Cupboard': 2.0, 'The Kid': 0, 'Epic': 3.5, 'Maleficent': 2.0, 'Alvin and the Chipmunks': 0, 'The Astronaut Farmer': 4, 'Men in Black': 12.0, 'The Polar Express': 2.0, 'The Sisterhood of the Traveling Pants 2': 0, 'Oz: The Great and Powerful': 3.0, 'Alpha and Omega: The Legend of the Saw Tooth Cave': 0, 'ParaNorman': 0, 'Return to Oz': 2.0, 'The Black Hole': 8.0, 'The Matrix Revolutions': 18.0, 'I, Robot': 3, 'The Flintstones': 0, 'Legend of the Guardians: The Owls of GaHoole': 2.0, 'Alvin and the Chipmunks: The Squeakquel': 0, 'Earth to Echo': 0, 'Fantastic Mr. Fox': 1.5, 'Pan': 3.0, 'Return to Never Land': 2.0, 'Spawn': 11.0, 'Holes': 0, 'The Spiderwick Chronicles': 2.0, 'Aquamarine': 0, 'The Wolverine': 11.0, 'Tuck Everlasting': 0, 'Charlottes Web': 0, 'The Covenant': 11.0, 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe': 3.0, 'X-Men: Days of Future Past': 11.0, 'Big': 0.0, 'Harry Potter and the Goblet of Fire': 4.0, 'Doctor Dolittle': 0, 'Bogus': 0, 'The Santa Clause 2': 3.0, 'Eragon': 5.0, 'The Nutty Professor': 3, 'Ratatouille': 0, 'Terminator Genisys': 11.5, 'The Wizard of Oz': 2.0, 'The NeverEnding Story': 3.0, 'Inspector Gadget': 4, 'Harry Potter and the Order of the Phoenix': 4.0, 'Kung Fu Panda': -1.5, 'Superman': 8.0, 'Army of Darkness': 0, 'Nanny McPhee': 0, 'Zoom': 0, 'Evan Almighty': 0, 'Harry Potter and the Chamber of Secrets': 4.0, 'TMNT': 5.5, 'Rio 2': 1.5, 'Bolt': 0, 'Flushed Away': 0, 'Nutty Professor II: The Klumps': 0, 'Up': 0, 'Babe': 0, 'Men in Black II': 10.0, 'Paul': 5.5, 'Idiocracy': 4, 'Osmosis Jones': 4, 'Monsters vs Aliens': 0, 'Antz': 3, 'Flubber': 0, 'Robots': 0, '3 Ninjas Kick Back': 4, 'The Brothers Grimm': 8.0, 'Cars': 0, 'Wild Wild West': 7.0, 'Dr. Dolittle 2': 0, 'Rango': 0, 'Cars 2': 0, 'Beastmaster 2: Through the Portal of Time': 7.5, 'Dragonball Evolution': 11.0, 'Petes Dragon': 2.0, 'Multiplicity': 3.0, 'Casper': 0, 'Superman Returns': 10.0, 'Just My Luck': 0.0, 'Mars Attacks!': 6, 'Percy Jackson: Sea of Monsters': 2.0, 'Time Changer': 0, 'Ice Age: The Meltdown': 0, 'The Flintstones in Viva Rock Vegas': 0, 'Hotel Transylvania': 3.0, 'Underworld: Rise of the Lycans': 11.0, 'Final Fantasy: The Spirits Within': 11.0, 'Snow Dogs': 0, 'The Lion of Judah': 0, 'The Muppet Movie': -3.0, 'Mary Poppins': 0, 'Paul Blart: Mall Cop': 4, 'The Adventures of Sharkboy and Lavagirl': 0, 'The Santa Clause': 0, 'Scooby-Doo 2: Monsters Unleashed': 0, 'The Sorcerers Apprentice': 7.0, 'The Muppet Christmas Carol': 0, 'Lost in Space': 0, 'A Sound of Thunder': 11.5, 'Alvin and the Chipmunks: The Road Chip': 0, 'My Favorite Martian': 0, 'Warlock' ...
# 0it [00:00, ?it/s]
# rating: 1.5 , movie: The Butterfly Effect
# rating: 3.0 , movie: Kindergarten Cop
# rating: 3.0 , movie: Lions for Lambs
# rating: 5.0 , movie: Men in Black II
# rating: 3.0 , movie: Seven Samurai
# rating: 4.5 , movie: Match Point
# rating: 2.0 , movie: Payback
# rating: 3.0 , movie: Wag the Dog
# rating: 4.0 , movie: Interview with the Vampire
# rating: 4.0 , movie: The Kite Runner
# rating: 0.5 , movie: Rebecca
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 4.0 , movie: Stand by Me
# rating: 3.0 , movie: Raiders of the Lost Ark
# rating: 3.0 , movie: Lawrence of Arabia
# rating: 2.5 , movie: Rosemarys Baby
# rating: 4.0 , movie: This Is 40
# rating: 4.0 , movie: Shine a Light
# rating: 4.5 , movie: Mission: Impossible
# rating: 3.0 , movie: Psycho
# rating: 4.0 , movie: Cinderella Man
# rating: 3.5 , movie: License to Wed
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 4.0 , movie: Deconstructing Harry
# rating: 5.0 , movie: Terminator 3: Rise of the Machines
# rating: 4.0 , movie: Pandoras Box
# rating: 3.5 , movie: Alvin and the Chipmunks
# rating: 5.0 , movie: Solaris
# rating: 5.0 , movie: Hannibal Rising
# rating: 5.0 , movie: The Talented Mr. Ripley
# rating: 3.0 , movie: Mr. Beans Holiday
# rating: 5.0 , movie: Escape from New York
# rating: 2.5 , movie: My Best Friends Wedding
# rating: 2.5 , movie: Maurice
# rating: 1.5 , movie: Mean Streets
# rating: 4.5 , movie: Confessions of a Dangerous Mind
# rating: 3.0 , movie: Jekyll and Hyde ... Together Again
# rating: 4.0 , movie: Harry Potter and the Philosophers Stone
# rating: 3.5 , movie: Titanic
# rating: 3.5 , movie: To Kill a Mockingbird
# rating: 5.0 , movie: The Wedding Planner
# rating: 3.0 , movie: Gothika
# rating: 5.0 , movie: A Woman, a Gun and a Noodle Shop
# rating: 3.0 , movie: Army of Darkness
# rating: 1.0 , movie: Notting Hill
# rating: 3.0 , movie: Manderlay
# rating: 1.0 , movie: 54
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 3.5 , movie: Along Came a Spider
# {'Jason Bourne': -1.5, 'Southland Tales': 10.5, 'The Bourne Identity': 1.5, 'The Battle of Shaker Heights': -0.5, 'Memento': -1.5, 'Crank': -0.5, 'Outside Providence': -3.5, 'Crank: High Voltage': -0.5, 'Mirrors': -0.5, 'Road Trip': -0.5, 'Varsity Blues': 1.0, 'Peaceful Warrior': -0.5, 'The Mighty': -0.5, 'Before I Go to Sleep': -0.5, 'Brooklyns Finest': 8.0, 'Se7en': 3, 'Bringing Out the Dead': -3.0, 'Disturbing Behavior': 3, 'First Blood': 8.0, 'Open Road': 0, 'One Missed Call': 6, 'Autumn in New York': 0, 'Love in the Time of Cholera': 6, 'Margaret': 0, 'City Hall': 0, 'Dredd': 0, 'Dancer in the Dark': 0, 'Proof of Life': 6.0, 'Legal Eagles': 5.0, 'No Strings Attached': 0, 'Stripes': 0, 'The Clan of the Cave Bear': 0, 'Six Days Seven Nights': 4, 'The Relic': 0, 'My Super Ex-Girlfriend': 6.0, 'Draft Day': 0, 'Twins': 0, 'The Shadow': 10.0, 'The Hunt': 0, 'Mr. Nice Guy': 0, 'The Last Samurai': 0, 'Crossroads': 4.0, 'The Man in the Iron Mask': 0, 'Apocalypto': 2.0, 'Die Hard': 6, 'Sahara': 4, 'Double Take': 4.0, 'A Passage to India': 0, 'The Adventures of Huck Finn': 0, 'American Ninja 2: The Confrontation': 0, 'The Hunger Games: Catching Fire': -2, 'Seven Years in Tibet': 0, 'Broken Arrow': 2.0, 'The Finest Hours': 0, 'The Kite Runner': 0, 'A Knights Tale': 0, 'Max': 0, 'Young Sherlock Holmes': 10.0, '47 Ronin': 0, 'One Mans Hero': 0, 'The Other Side of Heaven': 0, 'All Is Lost': 0, 'Sands of Iwo Jima': 0, 'The Negotiator': 10.0, 'Executive Decision': 2.0, 'Extreme Ops': 2.0, 'King Kong': 0, 'Alive': 2.0, 'The Host': 14.0, 'The Patriot': 0, 'Green Zone': 2.0, 'Gladiator': 0, 'The Hunting Party': 2.0, 'Congo': 10.0, 'All the Kings Men': 3, 'Madison': 0, 'White Fang': 3.0, 'Free State of Jones': 0, 'Quigley Down Under': 0, 'Walking Tall': 2.0, 'Robin and Marian': 1.5, 'The Count of Monte Cristo': 3.5, 'The Longest Day': 0, 'Gridiron Gang': 0, 'Knowing': 10.0, 'Rockaway': 0, '55 Days at Peking': 0, 'Supercross': 0, 'The Monuments Men': 4.5, 'The Legend of Hells Gate: An American Conspiracy': 0, 'The Sorcerers Apprentice': 7.0, 'The Muppet Christmas Carol': 0, 'Nowhere to Run': 2.0, 'Exodus: Gods and Kings': 0, 'Young Guns': 0, 'The Musketeer': 0, 'Heavens Gate': 0, 'Crossover': 0, 'The Charge of the Light Brigade': 0, 'Twister': 0, 'The Bounty': 0, 'First Knight': 0, 'Poseidon': 8.0, 'The Huntsman: Winters War': 3.0, 'In the Name of the King: A Dungeon Siege Tale': 0, 'Flight of the Phoenix': 2.0, 'Dark City': 0, 'Windtalkers': 0, 'Letters from Iwo Jima': 0, 'Braveheart': 0, 'Flight of the Intruder': 2.0, 'Highway': 0, 'The Glimmer Man': 10.0, 'The Great Escape': 0, 'Undisputed': 2.0, 'The Mortal Instruments: City of Bones': 0, 'United 93': 12.0, 'xXx: State of the Union': 10.0, 'Action Jackson': 6.0, 'The Edge': 0, 'Nicholas Nickleby': 0, 'In the Heart of the Sea': 3.5, 'Observe and Report': 2.0, 'Turbo': 1.5, 'Bloody Sunday': 0, 'The Legend of Bagger Vance': 3, 'World Trade Center': 6, 'Rock of Ages': 4.5, 'Tombstone': 0, 'Fury': 0, 'Interview with the Vampire': 0, 'The Last of the Mohicans': 2.0, 'Pompeii': 2.0, 'The Giver': 0, 'Marvins Room': -1.5, 'The Vatican Tapes': 0, 'Saints and Soldiers': 0, 'Rabbit-Proof Fence': 0, 'Alexander': 2.0, 'Tora! Tora! Tora!': 0, 'The Color of Money': 1.5, 'Adaptation.': 2.0, 'Magnolia': 1.5, 'The Homesman': 0, 'The Horse Whisperer': 1.5, 'The Manchurian Candidate': 1.5, 'The Messenger: The Story of Joan of Arc': 0, 'End of Watch': 8.0, 'Ordinary People': 0, 'The Ant Bully': 3.5, 'The Hours': 0, 'Shooter': 8.0, 'Red Tails': 0, 'Fantastic Mr. Fox': 0, 'The Conspirator': 0, 'Flyboys': 2.0, 'The Lucky Ones': 0, 'Crash': 0, 'Snow Falling on Cedars': 0, 'Vantage Point': 0, 'Wag the Dog': 1, 'Damnation Alley': 0, 'Rendition': 0.5, 'Men in Black': 13.0, 'Small Soldiers': 5.5, 'Jurassic World': 7.0, 'Star Wars: Clone Wars: Volume 1': 1, '3000 Miles to Graceland': 5.0, 'Land of the Lost': 1, 'Nothing to Lose': 1, 'Zombie Hunter': 5, 'Alien': 7, 'Night at the Museum: Battle of the Smithsonian': 3.0, ' ...
# 0it [00:00, ?it/s]
# rating: 4.0 , movie: Rambo III
# rating: 3.5 , movie: Aliens vs Predator: Requiem
# rating: 5.0 , movie: Escape from New York
# rating: 3.0 , movie: Gothika
# rating: 5.0 , movie: Letters from Iwo Jima
# rating: 2.5 , movie: My Best Friends Wedding
# rating: 3.5 , movie: Along Came a Spider
# rating: 4.0 , movie: Interview with the Vampire
# rating: 2.0 , movie: Payback
# rating: 5.0 , movie: The First Wives Club
# rating: 3.5 , movie: In Time
# rating: 4.0 , movie: Dear Frankie
# rating: 4.5 , movie: The Island
# rating: 4.0 , movie: This Is 40
# rating: 2.0 , movie: Dragonslayer
# rating: 3.5 , movie: To Kill a Mockingbird
# rating: 0.5 , movie: Y Tu Mamá También
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 0.5 , movie: Live and Let Die
# rating: 4.0 , movie: The Transporter
# rating: 3.0 , movie: Army of Darkness
# rating: 1.5 , movie: Mean Streets
# rating: 5.0 , movie: Hannibal Rising
# rating: 3.0 , movie: Raiders of the Lost Ark
# rating: 3.0 , movie: Bill & Teds Bogus Journey
# rating: 5.0 , movie: The Forbidden Kingdom
# rating: 3.0 , movie: Mr. Beans Holiday
# rating: 1.0 , movie: Rocky Balboa
# rating: 4.5 , movie: U-571
# rating: 4.0 , movie: Flash Gordon
# rating: 4.0 , movie: Shopgirl
# rating: 4.0 , movie: Deconstructing Harry
# rating: 2.5 , movie: Maurice
# rating: 3.5 , movie: Star Trek: Generations
# rating: 0.5 , movie: Amadeus
# rating: 2.0 , movie: The Last Emperor
# rating: 4.0 , movie: Superman
# rating: 2.5 , movie: Freddy vs. Jason
# rating: 1.0 , movie: Notting Hill
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 3.0 , movie: Seven Samurai
# rating: 4.5 , movie: Confessions of a Dangerous Mind
# rating: 2.0 , movie: The Sixth Sense
# rating: 2.0 , movie: Moulin Rouge!
# rating: 4.0 , movie: The Kite Runner
# rating: 4.5 , movie: Match Point
# rating: 3.5 , movie: Alvin and the Chipmunks
# rating: 3.0 , movie: Spellbound
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 5.0 , movie: The Wedding Planner
# {'Rambo: First Blood Part II': 10.0, 'Jurassic World': 4.0, '3000 Miles to Graceland': 6.5, 'Mission: Impossible - Ghost Protocol': 2.5, 'Apocalypto': 8.5, 'Knock Off': 2.5, 'The Jackal': 4.5, 'Street Fighter: The Legend of Chun-Li': 4.0, 'Charlies Angels': 6.5, 'Planet of the Apes': 4.0, 'Green Lantern': 8.5, 'X2': 5.0, 'The Spy Who Loved Me': -5.5, 'Lethal Weapon 4': 8.0, 'Anacondas: The Hunt for the Blood Orchid': 4.0, 'Without a Paddle': 2.5, 'G.I. Joe: The Rise of Cobra': 4.0, 'Dick Tracy': 6.5, '300': 7.5, 'Star Trek V: The Final Frontier': 4.0, 'Lara Croft: Tomb Raider': 8.5, 'Tora! Tora! Tora!': 8.5, 'Lucky Numbers': 8.0, 'Lethal Weapon 3': 8.0, 'RED': 6.5, 'Speed 2: Cruise Control': 2.5, 'Bad Boys II': 6.5, 'Broken Arrow': 8.5, 'Killer Elite': 1.0, 'Serenity': 4.0, 'The Fugitive': 4.5, 'The Matrix Revolutions': 12.5, 'Red Tails': 5.5, 'Spawn': 7.5, 'Sorcerer': 2.5, 'Vertical Limit': 4.0, 'Young Sherlock Holmes': 12.5, 'Star Trek III: The Search for Spock': 4.0, 'The Covenant': 6.5, 'Cliffhanger': 2.5, 'RoboCop 3': 12.0, 'The Saint': 4.0, 'Never Say Never Again': -1.5, 'The Big Hit': 2.5, 'A View to a Kill': -2.5, 'Moonraker': 0.0, 'X-Men Origins: Wolverine': 5.0, 'Terminator Genisys': 4.0, 'The Negotiator': 14.5, 'Executive Decision': 8.5, 'Extreme Ops': 10.0, 'Act of Valor': 2.5, 'Alive': 8.5, 'The Last of the Mohicans': 5.5, 'The World Is Not Enough': -1.5, 'The Green Inferno': 2.5, 'The Day After Tomorrow': 4.0, 'The Host': 14.0, 'The Island': 4.0, 'Race to Witch Mountain': 7.5, 'Changing Lanes': 3.0, 'The Core': 4.0, 'The Hunting Party': 8.5, 'Congo': 10.0, 'Daylight': 2.5, 'Maximum Risk': 2.5, 'Bad Company': 2.5, 'The Rock': 2.5, 'The Forsaken': 2.5, 'The Brothers Grimm': 4.5, 'Battleship': 4.0, 'Space Cowboys': 5.5, 'Free State of Jones': 6.0, 'Cirque du Freak: The Vampires Assistant': 8.5, 'Dragonball Evolution': 7.5, 'The Abyss': 4.0, 'Hollywood Homicide': 2.5, 'U-571': 4.5, 'Walking Tall': 8.5, 'The Count of Monte Cristo': 8.5, 'Knowing': 6.0, 'Lara Croft Tomb Raider: The Cradle of Life': 4.5, 'G.I. Joe: Retaliation': 4.0, 'Escape from L.A.': 7.0, 'Mad Max: Fury Road': 6.5, 'Shaft': 4.5, 'The Expendables': 1.0, 'Underworld: Rise of the Lycans': 10.5, 'Final Fantasy: The Spirits Within': 7.5, 'Quantum of Solace': 2.0, 'Casino Royale': -1.5, 'The Living Daylights': -4.5, 'Nowhere to Run': 8.5, 'Alexander': 10.5, 'Inception': 2.5, 'A Sound of Thunder': 0.0, 'Starship Troopers': 4.0, 'Star Trek: Generations': 4.0, 'Predator': 4.0, '9': 4.0, 'Lone Survivor': 8.5, 'The Shadow': 9.0, 'Mission: Impossible': -0.5, 'Armageddon': 4.0, 'Paycheck': 6.5, 'The Charge of the Light Brigade': 10.5, 'Hanna': -1.5, 'Into the Blue': 4.5, 'Licence to Kill': -3.5, 'Flyboys': 5.5, 'The River Wild': 4.5, 'Assassins': 7.5, 'Skyfall': -1.5, 'Star Trek: First Contact': 4.0, 'Child 44': 1.5, 'Ronin': 0.5, 'In the Heart of the Sea': 8.5, 'Mission: Impossible II': 0.5, 'Poseidon': 9.5, 'Predators': 4.0, 'Ballistic: Ecks vs. Sever': 2.5, 'I Spy': 2.5, 'DOA: Dead or Alive': -1.5, 'Cellular': 4.5, 'Flight of the Phoenix': 8.5, 'Fantastic 4: Rise of the Silver Surfer': 4.5, 'The Hunt for Red October': 2.5, 'Street Fighter': 2.5, 'The Three Musketeers': -1.5, 'Southland Tales': 12.0, 'On Her Majestys Secret Service': -5.5, 'Thunderball': -1.5, 'The Expendables 3': 2.5, 'Saints and Soldiers': 5.5, 'Star Trek: Insurrection': 4.0, 'Letters from Iwo Jima': 2.5, 'Dantes Peak': 2.5, 'Chain of Command': 2.5, 'Proof of Life': 12.5, 'Flight of the Intruder': 8.5, 'The Matrix Reloaded': 12.5, '16 Blocks': 6.0, 'GoldenEye': -3.5, 'Star Trek II: The Wrath of Khan': 4.0, 'Star Trek VI: The Undiscovered Country': 4.0, 'Switchback': 2.5, 'Commando': 2.5, 'The Glimmer Man': 14.5, 'The Great Escape': 9.5, 'The Expendables 2': 2.5, 'Undisputed': 8.5, 'The Losers': 4.5, 'X-Men: The Last Stand': 1.0, 'xXx: State of the Union': 14.5, 'Die Another Day': -1.5, 'Diamonds Are Forever': -3.5, 'Star Trek: Nemesis': 4.0, 'Jurassic Park III': 4.0, 'Green Zone': 5.5, 'Fortr ...
# 0it [00:00, ?it/s]
# rating: 5.0 , movie: Hannibal Rising
# rating: 2.0 , movie: Payback
# rating: 3.5 , movie: Open Season
# rating: 5.0 , movie: The Wedding Planner
# rating: 4.0 , movie: Shopgirl
# rating: 3.5 , movie: To Kill a Mockingbird
# rating: 4.0 , movie: Dear Frankie
# rating: 2.5 , movie: Rosemarys Baby
# rating: 4.0 , movie: Harry Potter and the Philosophers Stone
# rating: 2.0 , movie: Moulin Rouge!
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 4.0 , movie: Stand by Me
# rating: 3.0 , movie: Wag the Dog
# rating: 5.0 , movie: Amélie
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 5.0 , movie: Space Jam
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
# rating: 4.0 , movie: This Is 40
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 2.5 , movie: My Best Friends Wedding
# rating: 4.0 , movie: Deconstructing Harry
# rating: 5.0 , movie: A Woman, a Gun and a Noodle Shop
# rating: 4.0 , movie: Flash Gordon
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 3.0 , movie: Gothika
# rating: 3.0 , movie: Army of Darkness
# rating: 4.0 , movie: Cinderella Man
# rating: 4.5 , movie: The Island
# rating: 3.5 , movie: In Time
# rating: 4.5 , movie: Charlie Wilsons War
# rating: 5.0 , movie: Escape from New York
# rating: 3.5 , movie: Along Came a Spider
# rating: 2.0 , movie: Being John Malkovich
# rating: 5.0 , movie: Dances with Wolves
# rating: 0.5 , movie: Rebecca
# rating: 4.0 , movie: Pandoras Box
# rating: 4.5 , movie: Match Point
# rating: 0.5 , movie: Live and Let Die
# rating: 3.5 , movie: Star Trek: Generations
# rating: 4.0 , movie: Barry Lyndon
# rating: 4.5 , movie: The Karate Kid
# rating: 1.5 , movie: The Butterfly Effect
# rating: 5.0 , movie: Madagascar
# rating: 3.5 , movie: License to Wed
# rating: 4.0 , movie: Superman
# rating: 3.0 , movie: Raiders of the Lost Ark
# rating: 5.0 , movie: Letters from Iwo Jima
# rating: 5.0 , movie: Solaris
# rating: 3.0 , movie: Lions for Lambs
# rating: 4.0 , movie: The French Connection
# {'Zulu': 1, 'The Life of David Gale': 3.0, 'Red Riding: In the Year of Our Lord 1974': 3.0, 'The Godfather: Part III': 3.0, 'Edge of Darkness': 3.0, 'The Proposition': 3.0, 'Trance': 3.0, 'Need for Speed': 5.0, 'Deadfall': 3.0, 'Harry Brown': 4.5, 'The Bank Job': 3.0, 'The International': 3.0, 'The Infiltrator': 3.0, 'The Counselor': 3.0, 'Blood and Wine': 4.5, 'Only God Forgives': 3.0, 'Hitman': 5.0, 'Frenzy': 0.0, 'The First Great Train Robbery': 3.0, 'Dead Mans Shoes': 3.0, 'Trash': 3.0, 'Donkey Punch': 3.0, 'London to Brighton': 3.0, 'Owning Mahowny': 3.0, 'Freeze Frame': 3.0, 'Sexy Beast': 3.0, 'Killing Zoe': 11.0, 'The Next Three Days': 2.5, 'The Crying Game': 2.5, 'The Good Thief': 3.0, 'Machine Gun McCain': 1, '3 Days to Kill': 5.0, 'The American': 3.0, 'Dark Blue': 5.0, 'Brother': 3.0, 'Man on Fire': 5.0, 'Layer Cake': -2.0, 'Match Point': 5.5, 'Romeo Is Bleeding': 5.0, 'Buffalo Soldiers': 3.0, 'Frailty': 6.0, 'Bound': 2.5, 'United 93': 5.0, 'Veronica Guerin': 3.0, 'The Baader Meinhof Complex': 1, 'Death to Smoochy': 3.0, 'Brighton Rock': 3.0, 'Colombiana': 1, 'Contraband': 5.0, 'Butterfly on a Wheel': 3.0, 'The Dark Knight': 9.0, 'Girl with a Pearl Earring': 1, '28 Days': 1, 'Rock Star': 1, 'The Silence of the Lambs': -3.0, 'Memoirs of a Geisha': 3.0, '300': 5, 'The Dark Hours': 1, 'Red Dragon': 1, 'The Texas Chainsaw Massacre: The Beginning': 1, 'Jason Goes to Hell: The Final Friday': 1, 'Black Christmas': 1, 'Friday the 13th Part VIII: Jason Takes Manhattan': 1, 'Untraceable': 1, 'The Devils Rejects': 1, 'Malevolence': 1, 'Narc': 4.0, 'Patriot Games': 4.0, 'Shooter': 4.0, 'Young Sherlock Holmes': 8.0, 'Murder by Numbers': 2.0, '3000 Miles to Graceland': 4.0, 'Clear and Present Danger': -1.5, 'The Newton Boys': 0, 'Wonderland': 2.0, 'Slow Burn': 2.0, 'Apocalypto': 6.0, 'Silverado': 0, 'All Good Things': 1.5, 'Defendor': 3.0, 'Kill Bill: Vol. 2': 2.0, 'Niagara': 2.0, 'Mystic River': 5.0, 'Repo Men': 4.0, 'The Jackal': 4.0, 'The Rainmaker': 3.5, 'Disclosure': 1.5, 'Out of Time': 2.0, 'Breakdown': 0, 'Ninja Assassin': 2.0, 'The Bourne Ultimatum': 0, 'The Girl with the Dragon Tattoo': 2.0, 'Charlies Angels': 4.0, 'Savages': 2.0, 'Whiteout': 2.0, 'Machete Kills': 2.0, 'Taxman': 2.0, 'Heist': 2.0, 'Stone Cold': 2.0, 'The November Man': 2.0, 'Chicago Overcoat': 2.0, 'Enemy of the State': 2.0, 'Outbreak': 2.0, 'Salvation Boulevard': 0, 'Set It Off': 0, 'Lethal Weapon 4': 5.5, 'Dick Tracy': 4.0, 'The Exorcism of Emily Rose': 2.0, 'From Dusk Till Dawn': 2.0, 'Brooklyn Rules': 0, 'Conspiracy Theory': -1.0, 'The Fast and the Furious': 2.0, 'The Last Stand': 2.0, 'Checkmate': 2.0, 'Lucky Numbers': 6.0, 'Lethal Weapon 3': 5.5, 'RED': 4.0, 'The Equalizer': 2.0, 'S.W.A.T.': 2.0, 'The Devils Own': 2.0, 'Swelter': 0, 'The Adventures of Ford Fairlane': 2.0, 'Bad Boys II': 4.0, 'The Mechanic': 2.0, 'The Talented Mr. Ripley': -1.0, 'Broken City': 2.0, 'Broken Arrow': 6.0, 'Firestarter': 0, 'Bad Boys': 3.5, 'Sleepers': 2.0, 'The Son of No One': 2.0, 'Cradle 2 the Grave': 0, 'Desperado': 2.0, 'Pride and Glory': 2.0, 'In Her Line of Fire': 6, 'Party Monster': 3.0, 'The Client': 2.0, 'The Finest Hours': 0, 'The Fugitive': 4.0, 'Vampires': 3, 'Jack Reacher': 2.0, 'The Quiet American': 2.0, 'Dinner Rush': 0, 'Brigham City': 2.0, 'Gone in Sixty Seconds': 2.0, 'Elysium': 2.0, 'Snakes on a Plane': -4.0, 'The Lincoln Lawyer': 2.0, 'Crank': 0.5, 'RoboCop 3': 11.5, 'Blood Work': 5.0, 'The Betrayed': 2.0, 'A History of Violence': 2.0, 'Albino Alligator': 2.0, 'Bullet to the Head': 2.0, 'Inside Man': 2.0, 'The Boondock Saints II: All Saints Day': 2.0, 'Paparazzi': 0, 'Bless the Child': 2.0, 'The Killer Inside Me': 2.0, 'Point Break': 2.0, 'Turbulence': 2.0, 'The Dead Girl': 3.0, 'The Iceman': 2.0, 'The Transporter': 2.0, 'Executive Decision': 6.0, 'Extreme Ops': 7.5, 'True Romance': 5.0, 'Deterrence': 0, 'Ladder 49': 0, 'Cop Land': 0, 'Alive': 6.0, 'Criminal Activities': 2.0, 'Striptease': 2.0, 'The Bodyguard': 2.0, 'White House Down': 0, 'Half Past  ...
# 0it [00:00, ?it/s]
# rating: 3.5 , movie
green Lantern': 14.0, 'X2': 10.0, 'Scott Pilgrim vs. the World': 1, 'Wild Hogs': 1, 'The Hunger Games: Mockingjay - Part 2': 3.0, 'Back to the Future Part III': 1, 'Jupiter Ascending': 9.0, 'Aliens in the Attic': 7.0, 'Anacondas: The Hunt for the Blood Orchid': 9.0, 'Lethal Weapon 4': 6.5, 'MacGruber': 1, 'G.I. Joe: The Rise of Cobra': 9.0, 'Without a Paddle': 3.0, 'Dick Tracy': 5.0, 'Double Take': 5, 'The Lost World: Jurassic Park': 3.0, 'Star Trek V: The Final Frontier': 9.0, 'Oblivion': 3.0, 'Lucky Numbers': 7.0, 'Lethal Weapon 3': 6.5, 'Bill & Teds Bogus Journey': 7.0, 'Dune': 3.0, 'RED': 5.0, 'The Hunger Games: Catching Fire': 3.0, 'The Astronaut Farmer': 4.0, 'Bad Boys II': 5.0, 'Lake Placid': 5, 'The Talented Mr. Ripley': -1.0, 'Dylan Dog: Dead of Night': 5, 'Serenity': 9.0, 'The Black Hole': 3.0, 'Transformers: Age of Extinction': 3.0, 'Enders Game': 3.0, 'The Matrix Revolutions': 19.0, 'Three Kings': 1, 'Captain America: The Winter Soldier': 4.5, 'The Ice Pirates': 1, 'American Hero': 1, 'Spawn': 12.5, 'The Wolverine': 10.0, 'The Time Machine': 3.0, 'Jurassic Park III': 9.0, 'Meet Dave': 1, 'Brave': 10.0, 'The Empire Strikes Back': 3.0, 'Star Trek III: The Search for Spock': 9.0, 'The Covenant': 11.5, 'The Saint': 9.0, 'Money Talks': 1, 'RoboCop 3': 19.0, 'Star Trek Beyond': 3.0, 'Treasure Planet': 9.0, 'Death Race 2000': 1, 'Logans Run': 9.0, 'Terminator 3: Rise of the Machines': 4.5, 'The Big Hit': 3.0, 'X-Men: Days of Future Past': 10.0, 'Aliens': 13, 'How to Train Your Dragon 2': 10.0, 'Moonraker': 15.0, 'Sphere': 3, 'The Avengers': 3.0, 'The Blood of Heroes': 3.0, 'Terminator Genisys': 9.0, 'X-Men Origins: Wolverine': 10.0, 'Planet 51': 7, 'O Brother, Where Art Thou?': 1, 'Shanghai Knights': 1, 'Inspector Gadget': 1, 'Guardians of the Galaxy': 3.0, 'Superman': 7.0, 'The Day After Tomorrow': 9.0, 'Pacific Rim': 4.5, 'Six-String Samurai': 3.0, 'The Host': 17.0, 'The Island': 10.5, 'Avengers: Age of Ultron': 4.0, 'Night at the Museum': 11.0, 'Last Action Hero': 11.0, 'Race to Witch Mountain': 18.5, 'Iron Man': 4.5, 'The Toxic Avenger': 1, 'The Core': 9.0, 'Mirror Mirror': 6.0, '30 Minutes or Less': 1, 'Back to the Future': 1, 'Hudson Hawk': 1, 'Congo': 15.0, 'Ant-Man': 3.0, 'Delgo': 6.0, 'Paul': 2.5, 'Bad Company': 3.0, 'Superman IV: The Quest for Peace': 5.0, 'Idiocracy': 7, 'Osmosis Jones': 5, 'Charlies Angels: Full Throttle': 1, 'Transformers: Dark of the Moon': 3.0, 'John Carter': 6.0, 'Star Trek': 9.0, 'Star Wars': 3.0, 'The Spirit': 8.5, 'The Brothers Grimm': 9.0, '3 Ninjas Kick Back': 1, 'Battleship': 9.0 ...
# 0it [00:00, ?it/s]
# rating: 2.0 , movie:
': 4, 'The Soloist': 0, 'The Croods': 2.0, 'Hamlet 2': 0, 'Major League': 0, 'Cyrus': 0.0, 'Very Bad Things': 0, 'Shrek Forever After': 3.5, 'The Green Hornet': 0, 'Death to Smoochy': 8, 'The Ballad of Jack and Rose': 0, 'What Happens in Vegas': 0, 'Captain Phillips': 0, 'Shrek': 2.0, 'Johnny Suede': -1.5, 'As It Is in Heaven': 1.0, 'The English Patient': 3.5, 'Basquiat': 2.5, 'O': -1.5, 'Outside Providence': -3.0, 'Reno 911!: Miami': 2.5, 'Harvard Man': -1.5, 'The Hudsucker Proxy': -1.5, 'Spring Breakers': -1.5, 'The Informers': -1.5, 'Edmond': -1.5, 'Shortbus': 1.5, 'Veronika Decides to Die': 1.5, 'Payback': 4.5, 'We Own the Night': 2.5, 'Bringing Out the Dead': 0.0, 'Just Looking': 1.5, 'Buffalo Soldiers': 6.5, 'Boogie Nights': -1.5, 'The Doors': -3.0, 'The Good Girl': -1.5, 'Get Shorty': 3.0, 'Sea of Love': -1.5, 'Desperado': 1.5, 'Factory Girl': 2.5, 'Bandidas': -0.5, 'Once Upon a Time in Mexico': -0.5, 'Kate & Leopold': -0.5, 'Mars Needs Moms': -0.5, 'Party Monster': 2.5, 'Fled': -0.5, 'Prefontaine': -0.5, 'The Oh in Ohio': -0.5, 'The Velocity of Gary': -0.5, 'After the Sunset': -0.5, 'Herbie Fully Loaded': 1.5, 'Grown Ups': -0.5, 'Garfield': -0.5, 'Rat Race': -0.5, 'Wild Wild West': 4.5, 'Sexy Beast': 3.5, 'Trainspotting': -2.5, 'Human Traffic': -0.5, 'Shooting Fish': -0.5, 'Irreversible': -0.5, 'Lilya 4-ever': -0.5, 'The Immigrant': 0.5, 'The Great Beauty': -0.5, 'The Wolf of Wall Street': -0.5, 'Madagascar: Escape 2 Africa': 4, 'Roar': 3, 'The Nutty Professor': 1, 'Bamboozled': 1, 'Bad Company': 9.0, 'Tales from the Crypt: Demon Knight': 1, 'A Low Down Dirty Shame': 1, 'Antz': 1, 'Menace II Society': 1, 'Reign Over Me': 4, 'Six Days Seven Nights': 3.0, 'The Longest Yard': 1, 'Grown Ups 2': 1, 'Penguins of Madagascar': 1, 'Madagascar 3: Europes Most Wanted': 1, 'Everyone Says I Love You': 6.5, 'Murder by Numbers': 1, 'Takers': 3.0, 'Bridesmaids': 3, 'The Hunted': 6.0, 'New York Stories': 3.0, 'Run All Night': 3.0, 'Slow Burn': 1, 'Edge of Darkness': 5, 'Tarnation': 3, 'All Good Things': 1, 'Niagara': 1, 'One Missed Call': 3, 'Sabotage': 3.0, 'Mystic River': 7, 'Deadfall': 5, 'The Rainmaker': 4.0, 'Amadeus': 3, 'Disclosure': 1, 'Faster': 3.0, 'Out of Time': 1, 'The Bourne Ultimatum': 6.5, 'The Girl with the Dragon Tattoo': 1, 'Savages': -0.5, 'Kiss of Death': 3.0, 'Hackers': 1.5, 'Lone Wolf McQuade': 1.0, 'Hitman': 7.0, 'The Exorcism of Emily Rose': 1, 'Armored': 3.0, 'The Apartment': 3.0, 'Training Day': 4.0, '10th & Wolf': 3.0, 'The Fast and the Furious: Tokyo Drift': 3.0, 'Boys and Girls': 2.0, 'Men in Black': 16.0, 'Scarface': 7.5, 'The American': 5, 'The Devils Own': 1, 'Point Blank': 3.0, 'Man on Fire': 7.0, 'Broken City': 1, 'Notting Hill': 5.0, 'No Reservations': 3, 'Sleepers': 1, 'The Son of No One': 1, 'Romeo Is Bleeding': 7.0, 'Toy Story 2': 3, 'Pride and Glory': 2.5, 'The Client': 1, 'The Flintstones': 3, 'Frailty': 5, 'Shooter': 3.0, ' ...
# 0it [00:00, ?it/s]
# rating: 3.0 , movie: Lawrence of Arabia
# rating: 5.0 , movie: Escape from New York
# rating: 2.5 , movie: Rosemarys Baby
# rating: 3.0 , movie: Kindergarten Cop
# rating: 5.0 , movie: A Woman, a Gun and a Noodle Shop
# rating: 3.0 , movie: Psycho
# rating: 2.0 , movie: The Sixth Sense
# rating: 5.0 , movie: Mission to Mars
# rating: 1.0 , movie: Rocky Balboa
# rating: 5.0 , movie: The Talented Mr. Ripley
# rating: 1.0 , movie: Under Siege 2: Dark Territory
# rating: 3.0 , movie: Lions for Lambs
# rating: 3.5 , movie: Aliens vs Predator: Requiem
# rating: 3.5 , movie: License to Wed
# rating: 4.0 , movie: Shopgirl
# rating: 4.5 , movie: The Island
# rating: 3.0 , movie: Jekyll and Hyde ... Together Again
# rating: 3.0 , movie: Bill & Teds Bogus Journey
# rating: 5.0 , movie: Solaris
# rating: 4.0 , movie: The French Connection
# rating: 0.5 , movie: Y Tu Mamá También
# rating: 2.0 , movie: Wasabi
# rating: 2.0 , movie: Dragonslayer
# rating: 5.0 , movie: Dances with Wolves
# rating: 3.0 , movie: Seven Samurai
# rating: 4.0 , movie: Dear Frankie
# rating: 3.0 , movie: Spellbound
# rating: 5.0 , movie: Madagascar
# rating: 4.0 , movie: Superman
# rating: 2.0 , movie: The Last Emperor
# rating: 5.0 , movie: Amélie
# rating: 4.0 , movie: The Legend of Suriyothai
# rating: 2.5 , movie: Transformers: Revenge of the Fallen
# rating: 5.0 , movie: The First Wives Club
# rating: 0.5 , movie: Amadeus
# rating: 2.5 , movie: Along Came Polly
# rating: 2.0 , movie: Notes on a Scandal
# rating: 3.0 , movie: Raiders of the Lost Ark
# rating: 1.0 , movie: Alexander
# rating: 3.0 , movie: Mr. Beans Holiday
# rating: 3.0 , movie: The Curse of the Jade Scorpion
# rating: 3.5 , movie: Somethings Gotta Give
# rating: 4.0 , movie: Deconstructing Harry
# rating: 2.5 , movie: Romeo + Juliet
# rating: 3.5 , movie: X-Men Origins: Wolverine
# rating: 4.0 , movie: Highlander: The Final Dimension
# rating: 3.0 , movie: Wag the Dog
# rating: 5.0 , movie: The Forbidden Kingdom
# rating: 1.5 , movie: Mean Streets
# rating: 2.0 , movie: My Super Ex-Girlfriend
# {'Kingdom of Heaven': 0, 'Gandhi': 0, 'The 13th Warrior': 6.0, 'War Horse': 0, 'Gods of Egypt': 0, 'In Her Line of Fire': 3, 'The Matrix Revolutions': 9.0, 'A Scanner Darkly': 3, 'Blade Runner': 6.0, 'Idiocracy': 3, 'Killing Zoe': 9.0, 'First Blood': 3.0, 'RoboCop 3': 8.5, 'The Matrix Reloaded': 9.0, 'The Matrix': 3, 'Total Recall': 13.0, 'Die Hard': 3, 'Live Free or Die Hard': 3, 'Æon Flux': 3, 'Hostage': 7, 'The Thing': 1, 'Escape from L.A.': 4.5, 'The Fog': 1, 'Ghosts of Mars': 1, 'The Wild Bunch': 1, 'Vampires': 1, 'Halloween': 1, 'The Lion of Judah': 1, 'Memoirs of an Invisible Man': 1, 'They Live': 3.0, 'Babylon A.D.': 4.5, 'Lockout': 1, 'District 9': 1.5, 'Collateral': 1, 'Wag the Dog': 1, 'Deliver Us from Evil': 0, 'The Devils Advocate': 0, 'End of Days': 0, 'Let Me In': 0, 'The Midnight Meat Train': 4, 'The Mothman Prophecies': 0, 'The Curse of Downers
': 0, 'Last Orders': -2, 'Revolutionary Road': 0, 'Rango': 4, 'Rebecca': 0, 'Crossroads': 6.5, 'Disturbing Behavior': 0, 'The Aviator': 0.0, 'Outside Providence': -4.5, 'EuroTrip': 0, 'Insomnia': 0, 'Happiness': 0, 'I, Frankenstein': 0, 'About Time': 0, 'Margaret': 0, 'Network': 0, 'Astro Boy': 0, 'Auto Focus': 0, 'The Life Aquatic with Steve Zissou': 0, 'Indiana Jones and the Kingdom of the Crystal Skull': 0, 'Dancer in the Dark': 0, 'Arthur Christmas': 3, 'Porkys': 0, 'Factory Girl': -1.5, 'Wild Things': 0, 'The Devils Advocate': 0, 'In the Land of Women': 3.0, 'Alex & Emma': -3, 'Dressed to Kill': 4.5, 'The Boy Next Door': 0, 'The Shipping News': 0, 'The Monuments Men': 2.0, 'Chronicle': 0, 'Love in the Time of Cholera': 1.0, 'Fast Times at Ridgemont High': 0, 'The Canyons': 0, 'Derailed': 0, 'Savage Grace': 3.0, 'Forrest Gump': -6.0, 'The Hotel New Hampshire': 0, 'The Good German': 3.0, 'Cinderella': 4, 'Good Luck Chuck': -6.0, 'The T ...
# precision: 0.5023822087035792
# recall: 0.34722222222222227
# f1: 0.409832565753229

# %% [markdown]
# ### Σχολιασμός
#
# Χωρίζουμε τις ταινίες που προτείνουμε μέσω της simple_recommender σε 5 σετ (με την κατάλληλη τροποποίηση στο πεδίο return της συνάρτησης - αντίστοιχο σχόλιο), ανάλογα με το επίπεδο ομοιότητας που έχουν. Με αυτόν τον τρόπο μπορούμε και εφαρνόζουμε διαφορετικά βάρη σε κάθε επίπεδο (από 5 στο υψηλότερο έως 1 στο χαμηλότερο) για να έχουμε πιο στοχευμένες προτάσεις. Εάν μία ταινία προταθεί μόνο μία φορά, επιλέγουμε να της εφαρμόσουμε το μικρότερο δυνατό βάρος, ανεξάρτητα του επιπέδου ομοιότητας.
#
# Παρατηρούμε ότι (προφανώς) όσο τα δείγματα αξιολογήσεων αυξάνονται τόσο ο αλγόριθμος προτείνει ταινίες με πιο πετυχημένο τρόπο. Αυτό θα σήμαινε ότι το σύστημα αποδίδει το μέγιστο δυνατό για τους χρήστες που το χρησιμοποιούν αρκετό καιρό (αν υποθέσουμε ότι αυτό θα σήμαινε και περισσότερες αξιολογήσεις) σε σχέση με κάποιον νέο χρήστη.
#
# Παρόλα αυτά, εάν αναλογιστούμε και την χρονική απόδοση του συστήματος, θα ήταν πιο δόκιμο να λαμβάναμε ένα μικρότερο πλήθος αξιολογήσεων, γύρω στο 20, καθώς ο αλγόριθμος βελτιώνεται ελάχιστα και ταυτόχρονα καθυστερεί δραματικά.
#
# Το ότι το Precision παραμένει πάντα κοντά στο 0.5 είναι κάτι φυσιολογικό εάν σκεφτούμε ότι σε ένα πραγματικό σύστημα προτάσεων ταινιών, όπως είναι οι πλατφόρμες Netflix, ERTflix, HBOmax, κλπ, από τις ταινίες που μας προτείνονται να παρακολουθήσουμε, σχεδόν 1 στις 2 είναι κάποια που μας αρέσει πραγματικά.
